# %% [markdown]
# **Put your name and student ID here.**

# %% [markdown]
# **ANLY 4100 - Data Analytics I**
#
# **Homework - Training models**

# %% [markdown]
# Apply the techniques covered in Chapter 4 - polynomial features, polynomial regression, Ridge Regression, and Lasso Regression - to analyze the dataset from *population_vs_day_ch4.csv*.

# %% [markdown]
# In this file, the population (in millions) of a species and the date are recorded.
#
# - **date** : the date
#
# - **day** : the index of the day, where 20190101 is assumed to be the first day and 20190102 the second day
#
# - **population** : the population (in millions) of the species
#
# Build data mining models using the three regression methods: polynomial regression, Ridge Regression, and Lasso Regression. Visualize the results and provide a brief analysis of the findings.
#
# Submit your Python code and analysis in a single .ipynb file.

# %% [markdown]
# ## Q1. (1 point)

# %% [markdown]
# Load the CSV file using pandas.

# %% [markdown]
# ## Q2. (4 points)

# %% [markdown]
# Use the 'day' feature to create polynomial features with a degree of 10 and include_bias set to False.
#
# Store the generated features in X_poly and display them.

# %% [markdown]
# ## Q3. (4 points)

# %% [markdown]
# Use X_poly and LinearRegression() to build a regression model.

# %% [markdown]
# ## Q4. (4 points)

# %% [markdown]
# Use X_poly and Ridge() with $\alpha=1$ to build a regression model.

# %% [markdown]
# ## Q5. (4 points)

# %% [markdown]
# Use X_poly and Lasso() with $\alpha=1$ to build a regression model.

# %% [markdown]
# ## Q6. (8 points)

# %% [markdown]
# Display the training dataset along with the three prediction models in a single figure, aiming to produce a figure similar to the example provided.

# %% [markdown]
# <img width="600" src='data:image/svg+xml;base64,...'/>

# %% [markdown]
# ## Q7. (5 points)

# %% [markdown]
# Provide comments on the generated figure and each prediction model. Discuss the differences between the model plots, evaluating each model's performance - whether good or bad - and explaining the reasons behind your assessment.

# %% [markdown]
# Provide your answer here.
