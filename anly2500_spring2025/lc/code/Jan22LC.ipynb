# %%
print("Please input your name:")

n = input()

print("Please input your age: ")
ageStr = input() # when you input the name, input your real name

infor = "My name is " + n
print(infor)

ageInt = int(ageStr)

newAgeInt = ageInt+1

infor = "My current age is " + str(ageInt)
print(infor)

infor = "My age after one year is " + str(newAgeInt)
print(infor)
# Out:
# Please input your name:
# Tom
# Please input your age:
# 20
# My name is Tom
# My current age is 20
# My age after one year is 21

# %%
# Python
# B () => C => C++ C++++ (C#) JavaScript
# Drive a car:
# Camry => Accord, Civic, Corola, Altima
#

# %%
# RAM: memory, store data, hotel, room card, variable
# =
# CPU:  2+3*4
# two rules to define a variable name: 1. letters _ 0-9 2. first char letter _ (not a number)
# arithmetic opeators: + - * /
# ** raise power
# % reminder
# // integer division
r1 = 4**2 #
# 99 00
# int16 int32 int64
# data types (room type)
# 10 20 -20: integer 4B
# 10.2 -0.3: double float 8B
# bool: True (1) False (0) 1B
# string: "Tom" '' ''' '''

# assignment (statement)
# =
# two steps in an assignment
# step 1: CPU runs (executes) the right hand side (expression). CPU stores 16 to RAM
# step 2: write the address of the result (16) to the variable r1

print(r1)
# print: function (name) machine
# print(): function call (press the button) parameters ingredients
print(r1+2)
print( 2+3*4 )
print( 3**2 )
print( 10/4 )
print(10//4)
print(10%4)

print(5%3)
# Out:
# 16
# 18
# 14
# 9
# 2.5
# 2
# 2
# 2
