# %%
print("Please input your name: ")
n = input()

print("Please input your grade: ")
gStr = input() # gStr is string

gDbl = float(gStr)

inforStr = "Hello "+ n +"."+ "Your grade is "+ str(gDbl)+" ."
print(inforStr)

# if else
if gDbl>90:
  print("Your grade is greater than 90.")
else:
  print("Your grade is not greater than 90.")
# Out:
# Please input your name:
# Your real name
# Please input your grade:
# 86.6
# Hello Your real name.Your grade is 86.6 .
# Your grade is not greater than 90.

# %%
# int: 0 -1 (accurate)
# double (float) (not accurate) 1.00
print(12-10) #print machine paratemer
# print()# function call
print(1.2-1.0)
# assignment (room number, address: C: pointer)
# function
# simple vs complex
# Out:
# 2
# 0.19999999999999996

# %%
# string
# 'tom' "" ''' ''' """"""""
s1 = "120.6" # 5B string
s2 = "2" # 1Byte string
print(120.6-2)
print("120.6-2")
print('120.6-2')
print("""120.6-2""")
# Out:
# 118.6
# 120.6-2
# 120.6-2
# 120.6-2

# %%
print(2+3)
# Out:
# 5

# %%
print("2+3")
# Out:
# 2+3

# %%
print("2"+3) # + - / * // % only work on numbers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4ce7a3691a6e> in <cell line: 0>()
# ----> 1 print("2"+3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(5%3)
# Out:
# 2

# %%
a1 = 2
print(a1+3)
# Out:
# 5

# %%
print("a1+3")
# Out:
# a1+3

# %%
# bool: True False (postive negative) 1B (True 1 False 0)
b1 = True
print(b1)

b2 = 3>2 #
print(b2)
# Out:
# True
# True
