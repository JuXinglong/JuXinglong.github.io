# %%
# Your name and student id

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March24LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March24LC

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March24LC'

# %%
# %ls
# Out:
# City.db  March24_LC_Pre.ipynb

# %%
# %pip install jupysql duckdb duckdb-engine --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 5.4 MB/s eta 0:00:00

# %%
# Load the SQL extension
# %load_ext sql

# %%
# Setting: Show all rows
# %config SqlMagic.displaylimit = None
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# connect to database file
# %sql sqlite:///City.db
# Out:
# Connecting to 'sqlite:///City.db'

# %%
# %sqlcmd tables
# Out:
# +------+
# | Name |
# +------+
# | data |
# +------+

# %%
# %sqlcmd columns -t data
# Out:
# +------------+---------+----------+---------+-------------+
# |    name    |   type  | nullable | default | primary_key |
# +------------+---------+----------+---------+-------------+
# |     ID     | INTEGER |  False   |   None  |      1      |
# |    City    |   TEXT  |   True   |   None  |      0      |
# |   State    |   TEXT  |   True   |   None  |      0      |
# | Population | INTEGER |   True   |   None  |      0      |
# |    lat     |   REAL  |   True   |   None  |      0      |
# |    lon     |   REAL  |   True   |   None  |      0      |
# +------------+---------+----------+---------+-------------+

# %%
# %%sql
# select *
# from data
# ;
# Out:
# Running query in 'sqlite:///City.db'
# +------+----------------------------+----------------------+------------+--------------------+---------------------+
# |  ID  |            City            |        State         | Population |        lat         |         lon         |
# +------+----------------------------+----------------------+------------+--------------------+---------------------+
# |  1   |         Marysville         |      Washington      |   63269    |     48.0517637     |     -122.1770818    |
# |  2   |           Perris           |      California      |   72326    |     33.7825194     |     -117.2286478    |
# |  3   |         Cleveland          |         Ohio         |   390113   |      41.49932      |     -81.6943605     |
# |  4   |         Worcester          |    Massachusetts     |   182544   | 42.262593200000005 |     -71.8022934     |
# |  5   |          Columbia          |    South Carolina    |   133358   |     34.0007104     |     -81.0348144     |
# ...

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March24LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March24LC

# %%
# %ls
# Out:
# City.db  March24_LC_Post.ipynb  March24_LC_Pre.html  tips.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March24LC'

# %%
# Q1
import pandas as pd

# %%
tips_df = pd.read_csv("tips.csv")
tips_df # ram dataframe
# Out:
#       ID  total_bill   tip     sex smoker   day    time  size
# 0      1       16.99  1.01  Female     No   Sun  Dinner     2
# 1      2       10.34  1.66    Male     No   Sun  Dinner     3
# 2      3       21.01  3.50    Male     No   Sun  Dinner     3
# 3      4       23.68  3.31    Male     No   Sun  Dinner     2
# 4      5       24.59  3.61  Female     No   Sun  Dinner     4
# ..   ...         ...   ...     ...    ...   ...     ...   ...
# 239  240       29.03  5.92    Male     No   Sat  Dinner     3
# 240  241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  242       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  243       17.82  1.75    Male     No   Sat  Dinner     2
# 243  244       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
cols = tips_df.columns
print(cols)
n = len(cols)
print(f"There are {n} columns in df.")
# Out:
# Index(['ID', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# There are 8 columns in df.

# %%
# T3
tips_sorted_df =tips_df.sort_values(by=["total_bill",'tip'],ascending=[False,False])
tips_sorted_df
# Out:
#       ID  total_bill    tip     sex smoker   day    time  size
# 170  171       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212  213       48.33   9.00    Male     No   Sat  Dinner     4
# 59    60       48.27   6.73    Male     No   Sat  Dinner     4
# 156  157       48.17   5.00    Male     No   Sun  Dinner     6
# 182  183       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..   ...         ...    ...     ...    ...   ...     ...   ...
# 149  150        7.51   2.00    Male     No  Thur   Lunch     2
# 172  173        7.25   5.15    Male    Yes   Sun  Dinner     2
# 111  112        7.25   1.00  Female     No   Sat  Dinner     1
# 92    93        5.75   1.00  Female    Yes   Fri  Dinner     2
# 67    68        3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 8 columns]

# %%
tips_sorted_df.to_csv("tips_sorted.csv",index=False)

# %%
# %ls
# Out:
# City.db  March24_LC_Post.ipynb  March24_LC_Pre.html  tips.csv  tips_sorted.csv

# %%
tips_sorted_df.head(10)
# Out:
#       ID  total_bill    tip     sex smoker   day    time  size
# 170  171       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212  213       48.33   9.00    Male     No   Sat  Dinner     4
# 59    60       48.27   6.73    Male     No   Sat  Dinner     4
# 156  157       48.17   5.00    Male     No   Sun  Dinner     6
# 182  183       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102  103       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197  198       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142  143       41.19   5.00    Male     No  Thur   Lunch     5
# 184  185       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95    96       40.17   4.73    Male    Yes   Fri  Dinner     4

# %%
tips_sorted_df.tail(10)
# Out:
#       ID  total_bill   tip     sex smoker   day    time  size
# 126  127        8.52  1.48    Male     No  Thur   Lunch     2
# 135  136        8.51  1.25  Female     No  Thur   Lunch     2
# 145  146        8.35  1.50  Female     No  Thur   Lunch     2
# 218  219        7.74  1.44    Male    Yes   Sat  Dinner     2
# 195  196        7.56  1.44    Male     No  Thur   Lunch     2
# 149  150        7.51  2.00    Male     No  Thur   Lunch     2
# 172  173        7.25  5.15    Male    Yes   Sun  Dinner     2
# 111  112        7.25  1.00  Female     No   Sat  Dinner     1
# 92    93        5.75  1.00  Female    Yes   Fri  Dinner     2
# 67    68        3.07  1.00  Female    Yes   Sat  Dinner     1

# %%
# T4
days = tips_df["day"].unique()
print(days) #

n = len(days)
print(f"There are {n} days.")
# Out:
# ['Sun' 'Sat' 'Thur' 'Fri']
# There are 4 days.

# %%
tips_df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
tips_df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
# T5
t = tips_df['total_bill'].sum()
print(f"The revenue is: ${t:.1f}")
# Out:
# The revenue is: $4827.8

# %%
# T6
gs = tips_df.groupby(by=["sex"])

# %%
gs.groups.keys()
# Out:
# dict_keys(['Female', 'Male'])

# %%
df = gs.get_group("Female")
print(df)
# Out:
#       ID  total_bill   tip     sex smoker   day    time  size
# 0      1       16.99  1.01  Female     No   Sun  Dinner     2
# 4      5       24.59  3.61  Female     No   Sun  Dinner     4
# 11    12       35.26  5.00  Female     No   Sun  Dinner     4
# 14    15       14.83  3.02  Female     No   Sun  Dinner     2
# 16    17       10.33  1.67  Female     No   Sun  Dinner     3
# ..   ...         ...   ...     ...    ...   ...     ...   ...
# 226  227       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229  230       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238  239       35.83  4.67  Female     No   Sat  Dinner     3
# 240  241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243  244       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 8 columns]
# ...

# %%
# %%shell
# jupyter nbconvert "March24_LC_Post.ipynb" --to html
# Out:
# [NbConvertApp] Converting notebook March24_LC_Pre.ipynb to html
# [NbConvertApp] Writing 282933 bytes to March24_LC_Pre.html
