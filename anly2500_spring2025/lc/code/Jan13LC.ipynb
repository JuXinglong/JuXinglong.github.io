# %%
print("Your real name here") # make sure you need to provdie your real name
print("You real student ID here")

print("3**2")
print("3 squred") # ctrl s
print(3**2)
# Out:
# Your real name here
# You real student ID here
# 3**2
# 3 squred
# 9

# %%
# Python
# RAM CPU
# RAM memory: store the data
# CPU: calculation
# hard drive: speed: 1000X (1 day) (1000 days)

# variables: RAM
# expressions: CPU 2+3+4-10
# RAM address is 1
#
# 1  2 3
age1 = 20 + 1 + 10
# = assignment operator
#left handside assignment
#right handside

# =
# age1: variable and store the room number

# letters numbers _
# the first char can only be letters or _ (could not be a number)
age2 = 19 #
# code statement

print( age1 )
print( age2 )

print( id(age1)  )
# Out:
# 31
# 19
# 135396267984048

# %%
# datatypes vs room types
# integer: whole number, number with no digit after decimal, 0,1,-1, 10, -20
# B: Byte 4B
# double (float): 1.23, 1.0, -1.2 (8B)
# string "1.23" 4B  "Tom" 3B
# bool (boolean): true false 1B

age3 = 21.6

name = "Kelly"

b1 = True

print(name)
print(b1)
# Out:
# Kelly
# True
