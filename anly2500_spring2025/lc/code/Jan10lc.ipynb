# %%
print("ANLY 2500") # This is the first line code.
# comment. is not code print("Hello")
print("Welcome")# code statement

# ipynb: interactive Python notebook
# Python: .py
# txt:
# docx
# xlsx
# Out:
# ANLY 2500
# Welcome

# %%
# Python programming language
# programming language:
# language:
# commands
# English Spanish Frech
# 1940s
# 1950s B (Basics Beginner)
# C
# C++
# C++++ # => C# (MS)
# Java (SUN) => Oracle
# JavaScript (LiveScript)

# %%
# use resources
# two computer resources:
# Memory (RAM): store data
# CPU (): + - / *

print(2+3*2)
# Out:
# 8
