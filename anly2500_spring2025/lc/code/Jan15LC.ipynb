# %%
print("Your real name here")
print('Your real id') # a pair of ' ' or a pair of " " are the same in Python
# Out:
# Your real name here
# Your real id

# %%
r = 2+3*2
print(r)
# Out:
# 8

# %%
# assignment
# function print()

# simple vs complex
w = 128.8 #code, statement, assignment
# = assignment operator
# w
age = 19+1 #code, statement, assignment
# expression
#
age = age + 1 # assignment
print(age)
# Out:
# 21

# %%
b = 100 + 20 # assignment, code, statement
print(b)#

# 130
b = b + 10 # assignment
print(b)
# Out:
# 120
# 130

# %%
# function (method)
b = 100 #
print(b) #
# print function (name)
# print() : function call
# parameter
b = b + 1 #
print(b)
# Out:
# 100
# 101
