# %%
# your name and student id

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March31LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March31LC

# %%
# %ls
# Out:
# City.db  March31_LC_pre.ipynb

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March31LC'

# %%
# %pip install jupysql duckdb duckdb-engine --quiet
# Load the SQL extension
# %load_ext sql
# Setting: Show all rows
# %config SqlMagic.displaylimit = None
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.2 MB/s eta 0:00:00
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %sql sqlite:///City.db
# Out:
# Connecting to 'sqlite:///City.db'

# %%
# %sqlcmd tables
# Out:
# +------+
# | Name |
# +------+
# | data |
# +------+

# %%
# %sqlcmd columns -t data
# Out:
# +------------+---------+----------+---------+-------------+
# |    name    |   type  | nullable | default | primary_key |
# +------------+---------+----------+---------+-------------+
# |     ID     | INTEGER |  False   |   None  |      1      |
# |    City    |   TEXT  |   True   |   None  |      0      |
# |   State    |   TEXT  |   True   |   None  |      0      |
# | Population | INTEGER |   True   |   None  |      0      |
# |    lat     |   REAL  |   True   |   None  |      0      |
# |    lon     |   REAL  |   True   |   None  |      0      |
# +------------+---------+----------+---------+-------------+

# %%
# avg() max() min() count() sum()
# %%sql
select State,
      sum(Population) as TotalPop, count(*) as N
from data
group by State
;
# Out:
# Running query in 'sqlite:///City.db'
# +----------------------+----------+-----+
# |        State         | TotalPop |  N  |
# +----------------------+----------+-----+
# |       Alabama        | 1279813  |  12 |
# |        Alaska        |  300950  |  1  |
# |       Arizona        | 4691466  |  25 |
# |       Arkansas       |  787011  |  10 |
# |      California      | 27910620 | 212 |
# |       Colorado       | 3012284  |  21 |
# |     Connecticut      | 1239817  |  15 |
# |       Delaware       |  108891  |  2  |
# | District of Columbia |  646449  |  1  |
# |       Florida        | 7410114  |  73 |
# |       Georgia        | 1995615  |  18 |
# |        Hawaii        |  347884  |  1  |
# |        Idaho         |  638333  |  8  |
# |       Illinois       | 6055539  |  52 |
# |       Indiana        | 2393472  |  21 |
# |         Iowa         | 1037690  |  13 |
# |        Kansas        | 1327215  |  11 |
# |       Kentucky       | 1079181  |  5  |
# ...

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March31LC'
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/March31LC

# %%
# %ls
# Out:
# City.db  March31_LC_pre.html  March31_LC_pre.ipynb  Students.db

# %%
# SQL: structured query language
# for database
# retrieve data from database
# database: relational database (most )

# %%
# pandas: module, package, library
# software
# numpy
# %pip install pandas numpy --quiet

# %%
# %pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.5.2
# aiohappyeyeballs                   2.6.1
# aiohttp                            3.11.14
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.5
# ale-py                             0.10.2
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              4.9.0
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.7.1
# arviz                              0.21.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.3.17.0.34.53
# astunparse                         1.6.3
# atpublic                           5.1
# ...

# %%
# %pip install jupysql duckdb duckdb-engine --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.2 MB/s eta 0:00:00

# %%
# Load the SQL extension
# %load_ext sql

# %%
# Setting: Show all rows
# %config SqlMagic.displaylimit = None
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %ls
# Out:
# City.db  March31_LC_post.ipynb  March31_LC_pre.html  Students.db

# %%
# SQLite, MS SQL, Oracle,
# %sql sqlite:///Students.db
# Out:
# Connecting to 'sqlite:///Students.db'

# %%
# %sqlcmd tables
# Out:
# +-------------+
# |     Name    |
# +-------------+
# |   Courses   |
# | Enrollments |
# |   Profiles  |
# |   Students  |
# +-------------+

# %%
# %sqlcmd columns -t Courses
# Out:
# +-------------+---------+----------+---------+-------------+
# |     name    |   type  | nullable | default | primary_key |
# +-------------+---------+----------+---------+-------------+
# |      Id     |   TEXT  |  False   |   None  |      1      |
# |     Name    |   TEXT  |  False   |   None  |      0      |
# | CreditHours | INTEGER |  False   |   None  |      0      |
# |   Created   |   TEXT  |  False   |   None  |      0      |
# +-------------+---------+----------+---------+-------------+

# %%
# %sqlcmd columns -t Students
# Out:
# +----------+------+----------+---------+-------------+
# |   name   | type | nullable | default | primary_key |
# +----------+------+----------+---------+-------------+
# |    Id    | TEXT |  False   |   None  |      1      |
# |   Name   | TEXT |  False   |   None  |      0      |
# |   DOB    | TEXT |  False   |   None  |      0      |
# | favPlace | TEXT |  False   |   None  |      0      |
# |   lon    | REAL |  False   |   None  |      0      |
# |   lat    | REAL |  False   |   None  |      0      |
# +----------+------+----------+---------+-------------+

# %%
# %sql sqlite:///City.db
# Out:
# Connecting and switching to connection 'sqlite:///City.db'

# %%
# %sqlcmd tables
# Out:
# +------+
# | Name |
# +------+
# | data |
# +------+

# %%
# %sqlcmd columns -t data
# Out:
# +------------+---------+----------+---------+-------------+
# |    name    |   type  | nullable | default | primary_key |
# +------------+---------+----------+---------+-------------+
# |     ID     | INTEGER |  False   |   None  |      1      |
# |    City    |   TEXT  |   True   |   None  |      0      |
# |   State    |   TEXT  |   True   |   None  |      0      |
# | Population | INTEGER |   True   |   None  |      0      |
# |    lat     |   REAL  |   True   |   None  |      0      |
# |    lon     |   REAL  |   True   |   None  |      0      |
# +------------+---------+----------+---------+-------------+

# %%
# in sql, string ' '
# %%sql
select City as C,
       Population as P
from data
where State='Utah' and Population>50000
;
# Out:
# Running query in 'sqlite:///City.db'
# +------------------+--------+
# |        C         |   P    |
# +------------------+--------+
# |   South Jordan   | 59366  |
# |      Provo       | 116288 |
# |   Taylorsville   | 60519  |
# |       Lehi       | 54382  |
# |      Ogden       | 84249  |
# |      Layton      | 70790  |
# |      Sandy       | 90231  |
# | West Valley City | 133579 |
# |       Orem       | 91648  |
# |    St. George    | 76817  |
# |   West Jordan    | 110077 |
# |  Salt Lake City  | 191180 |
# +------------------+--------+

# %%
# count() max() min() avg()
# %%sql
select State,
       count(*) as NRows,
       max(Population) as MaxPop,
       avg(Population) as AvgPop
from data
group by State
;
# Out:
# Running query in 'sqlite:///City.db'
# +----------------------+-------+---------+--------------------+
# |        State         | NRows |  MaxPop |       AvgPop       |
# +----------------------+-------+---------+--------------------+
# |       Alabama        |   12  |  212113 | 106651.08333333333 |
# |        Alaska        |   1   |  300950 |      300950.0      |
# |       Arizona        |   25  | 1513367 |     187658.64      |
# |       Arkansas       |   10  |  197357 |      78701.1       |
# |      California      |  212  | 3884307 | 131653.8679245283  |
# |       Colorado       |   21  |  649495 | 143442.09523809524 |
# |     Connecticut      |   15  |  147216 | 82654.46666666666  |
# |       Delaware       |   2   |  71525  |      54445.5       |
# | District of Columbia |   1   |  646449 |      646449.0      |
# |       Florida        |   73  |  842583 | 101508.4109589041  |
# |       Georgia        |   18  |  447841 |      110867.5      |
# ...

# %%
# %%shell
# jupyter nbconvert "March31_LC_post.ipynb" --to html
# Out:
# [NbConvertApp] Converting notebook March31_LC_pre.ipynb to html
# [NbConvertApp] Writing 285637 bytes to March31_LC_pre.html
