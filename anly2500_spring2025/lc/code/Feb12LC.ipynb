# %%
# your student name and id
# loop: for loop & while loop
# for loop: loop is to repeat doing things
# collections: list & dictionary
l1 = [3,60,6,10]
print( len(l1) )

for i in l1:
  print(f"This is {i}")
  print("This is being excuted")
# Out:
# 4
# This is 3
# This is being excuted
# This is 60
# This is being excuted
# This is 6
# This is being excuted
# This is 10
# This is being excuted

# %%
import random as r # file module library
# define counter/accumulator variables # bank balance
nQ = 0 # int
nC = 0 # number correct
nW = 0 # number wrong answers
nP = 0 # total points

# generate question ()

# 1
nQ = nQ + 1 #
n1 = r.randint(0,9) # 0 1
n2 = r.randint(0,9) #
print(f"\n\nQ{nQ}: {n1} + {n2} = ?")
print("Input the answer:")
aStr = input() #
aInt = int(aStr) # user answer
gtInt = n1+n2 # ground truth

if aInt==gtInt: # user is correct
  print("Correct!")
  nC=nC+1
  nP=nP+2 #
else:
  print("Wrong!")
  nW = nW+1
  nP=nP-3

# 2
nQ = nQ + 1 #
n1 = r.randint(0,9) # 0 1
n2 = r.randint(0,9) #
print(f"\n\nQ{nQ}: {n1} + {n2} = ?")
print("Input the answer:")
aStr = input() #
aInt = int(aStr) # user answer
gtInt = n1+n2 # ground truth

if aInt==gtInt: # user is correct
  print("Correct!")
  nC=nC+1
  nP=nP+2 #
else:
  print("Wrong!")
  nW = nW+1
  nP=nP-3

# 3
nQ = nQ + 1 #
n1 = r.randint(0,9) # 0 1
n2 = r.randint(0,9) #
print(f"\n\nQ{nQ}: {n1} + {n2} = ?")
print("Input the answer:")
aStr = input() #
aInt = int(aStr) # user answer
gtInt = n1+n2 # ground truth

if aInt==gtInt: # user is correct
  print("Correct!")
  nC=nC+1
  nP=nP+2 #
else:
  print("Wrong!")
  nW = nW+1
  nP=nP-3

# summary
print(f"\n\n\nN Q: {nQ}")
print(f"Correct: {nC}/{nQ} ({nC/nQ:.2%})")

if nP>0:
  print("Congrats")
elif nP==0:
  print("It is 0 points")
else:
  print("Sorry! Negative points")
# Out:
# Q1: 1 + 5 = ?
# Input the answer:
# 1
# Wrong!
#
#
# Q2: 2 + 3 = ?
# Input the answer:
# 1
# Wrong!
#
#
# Q3: 0 + 1 = ?
# Input the answer:
# 1
# Correct!
#
#
#
# N Q: 3
# Correct: 1/3 (33.33%)
# Sorry! Negative points
