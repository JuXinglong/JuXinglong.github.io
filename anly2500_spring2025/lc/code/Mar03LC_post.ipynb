# %%
# your name and student id
# %cat /etc/hostname # print out your computer id
# Out:
# 24c4237a6692

# %%
# change the current folder ctrl v to paste
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar03LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar03LC

# %%
# %ls
# Out:
# Mar03LC.ipynb  us-cities-top-1k.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar03LC'

# %%
import pandas as pd
df=pd.read_csv("us-cities-top-1k.csv")
print(df)
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
# Python
# assignment ()
# function () => how define function
# simple vs complex

# Pandas Python (Project)
# Matplotlib Python
# SQL (database) (Project)
# Tableau (data visualization) (Project)

# Cloud computing platform
# Email,
# service (pay)
# beef 0.56 pounds
# 1 computer (32GB RAM, 1TB for HD,) $1000
#
# 36 computers
# $3000
# 24 hours/day
# only a few hours
#

# OS: windows, iOS, Android, (not free)
# Linux: Ubuntu (free)

# file (csv: comma seperated values)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# cd: change directory, folder
# ls: show file
# pwd: show the current folder

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar03LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar03LC

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar03LC'

# %%
# %ls
# Out:
# Mar03LC.html  Mar03LC_post.ipynb  us-cities-top-1k.csv

# %%
# module, library (the code in another file)
import random

# %%
# %ls
# Out:
# Mar03LC.html  Mar03LC_post.ipynb  mylib1.py  mylib2.py  us-cities-top-1k.csv

# %%
import mylib1
print(mylib1.age1) # tom's
import mylib2
print(mylib2.age1)
# Out:
# 10
# 30

# %%
import mylib1 as m1
print(m1.age1)
# Out:
# 10

# %%
# %%shell
# jupyter nbconvert "Mar03LC_post.ipynb" --to html
# Out:
# [NbConvertApp] Converting notebook Mar03LC_post.ipynb to html
# [NbConvertApp] Writing 289813 bytes to Mar03LC_post.html
