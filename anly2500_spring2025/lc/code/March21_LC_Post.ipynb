# %%
# your name and student id

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar21LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar21LC

# %%
# %ls
# Out:
# March21_LC_Pre.ipynb  us-cities-top-1k.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar21LC'

# %%
import pandas as pd

# %%
df = pd.read_csv("us-cities-top-1k.csv")
df
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
# group by: divide one bid dataframe into small dataframes
gs = df.groupby(by=["State"]) # into small ones based on the states

# %%
# gs: 51 dataframe

# %%
gs.groups.keys()
# Out:
# dict_keys(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'])

# %%
for s in gs.groups.keys():
  print(s)
# Out:
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming

# %%
s_df = gs.get_group("Texas") # get the dataframe only contains cities in Texas
s_df
# Out:
# <ipython-input-10-e07ca19fa4f7>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   s_df = gs.get_group("Texas") # get the dataframe only contains cities in Texas
#                      City  State  Population        lat         lon
# 20                Lubbock  Texas      239538  33.577863 -101.855166
# 28                Rowlett  Texas       58043  32.902902  -96.563880
# 38   North Richland Hills  Texas       67317  32.834295  -97.228903
# 59                 Dallas  Texas     1257676  32.776664  -96.796988
# 114             Texarkana  Texas       37442  33.425125  -94.047688
# ..                    ...    ...         ...        ...         ...
# 921             Arlington  Texas      379577  32.735687  -97.108066
# 922            Lewisville  Texas      101074  33.046233  -96.994174
# ...

# %%
s_df.to_csv("texas_city.csv",index=False)

# %%
# %ls
# Out:
# March21_LC_Pre.ipynb  texas_city.csv  us-cities-top-1k.csv

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar21LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar21LC

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar21LC'

# %%
# %ls
# Out:
# March21_LC_Pre.html  March21_LC_Pre.ipynb  texas_city.csv  us-cities-top-1k.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("us-cities-top-1k.csv")
df# dataframe, table, sheet
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
# groupby(by=[])
# divide a signle dataframe into small ones
df.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
states = df["State"].unique() # indexer, collection, series
states
# Out:
# array(['Washington', 'California', 'Ohio', 'Massachusetts',
#        'South Carolina', 'Connecticut', 'Minnesota', 'Michigan',
#        'Louisiana', 'Idaho', 'Indiana', 'Georgia', 'Colorado', 'Florida',
#        'Illinois', 'Virginia', 'Texas', 'Kansas', 'Mississippi',
#        'North Carolina', 'Missouri', 'New Mexico', 'Alabama', 'Utah',
#        'Pennsylvania', 'New York', 'Wisconsin', 'Arkansas',
#        'Rhode Island', 'Iowa', 'Nevada', 'Tennessee', 'Wyoming',
#        'Maryland', 'North Dakota', 'Oregon', 'Arizona', 'Maine',
#        'Nebraska', 'New Jersey', 'Montana', 'Oklahoma', 'West Virginia',
#        'South Dakota', 'District of Columbia', 'New Hampshire', 'Alaska',
#        'Delaware', 'Kentucky', 'Hawaii', 'Vermont'], dtype=object)

# %%
len(states)
# Out:
# 51

# %%
c1 = df["State"]=="Utah" # assignment
c1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: State, Length: 1000, dtype: bool

# %%
df[c1]
# Out:
#                  City State  Population        lat         lon
# 31              Logan  Utah       48913  41.736980 -111.833836
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 285         Bountiful  Utah       43023  40.889390 -111.880771
# 381             Provo  Utah      116288  40.233844 -111.658534
# 434      Spanish Fork  Utah       36956  40.114955 -111.654923
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 466          Riverton  Utah       40921  40.521893 -111.939102
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 568            Layton  Utah       70790  41.060222 -111.971053
# 603            Murray  Utah       48612  40.666892 -111.887991
# 630             Sandy  Utah       90231  40.564978 -111.838973
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 676              Orem  Utah       91648  40.296898 -111.694648
# ...

# %%
gs = df.groupby(by=["State"]) # 51 states,

# %%
# all the labels (group names)
gs.groups.keys() # collection
# Out:
# dict_keys(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'])

# %%
df1 = gs.get_group("Utah") #
df1
# Out:
# <ipython-input-20-2249208e60e2>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   df1 = gs.get_group("Utah") #
#                  City State  Population        lat         lon
# 31              Logan  Utah       48913  41.736980 -111.833836
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 285         Bountiful  Utah       43023  40.889390 -111.880771
# 381             Provo  Utah      116288  40.233844 -111.658534
# 434      Spanish Fork  Utah       36956  40.114955 -111.654923
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 466          Riverton  Utah       40921  40.521893 -111.939102
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 568            Layton  Utah       70790  41.060222 -111.971053
# ...

# %%
# sort_values()
df1.sort_values(by=["Population"],ascending=[False])
# Out:
#                  City State  Population        lat         lon
# 964    Salt Lake City  Utah      191180  40.760779 -111.891047
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 381             Provo  Utah      116288  40.233844 -111.658534
# 955       West Jordan  Utah      110077  40.609670 -111.939103
# 676              Orem  Utah       91648  40.296898 -111.694648
# 630             Sandy  Utah       90231  40.564978 -111.838973
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 856        St. George  Utah       76817  37.096528 -113.568416
# 568            Layton  Utah       70790  41.060222 -111.971053
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 31              Logan  Utah       48913  41.736980 -111.833836
# 603            Murray  Utah       48612  40.666892 -111.887991
# ...

# %%
#
gs = df.groupby(by=["State"])

# %%
states = gs.groups.keys() # collection
states#print(states)
# Out:
# dict_keys(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'])

# %%
for i in states:
  print(i)
  s_df = gs.get_group(i)
  print(s_df)
  s_df.to_csv(f"d1/{i}.csv")
# Out:
# Alabama
#             City    State  Population        lat        lon
# 30    Montgomery  Alabama      201332  32.366805 -86.299969
# 248   Birmingham  Alabama      212113  33.520661 -86.802490
# 306   Huntsville  Alabama      186254  34.730369 -86.586104
# 319      Madison  Alabama       45799  34.699258 -86.748332
# 388       Mobile  Alabama      194899  30.695366 -88.039891
# 412   Tuscaloosa  Alabama       95334  33.209841 -87.569174
# 415       Hoover  Alabama       84126  33.405387 -86.811378
# 455      Decatur  Alabama       55816  34.605925 -86.983342
# 614       Auburn  Alabama       58582  32.609857 -85.480782
# 742     Florence  Alabama       40059  34.799810 -87.677251
# 835  Phenix City  Alabama       37498  32.470976 -85.000765
# 934       Dothan  Alabama       68001  31.223231 -85.390489
# Alaska
#           City   State  Population        lat         lon
# 370  Anchorage  Alaska      300950  61.218056 -149.900278
# Arizona
# ...

# %%
# %%shell
# jupyter nbconvert "March21_LC_Post.ipynb" --to html
# Out:
# [NbConvertApp] WARNING | pattern 'March21_LC_Post.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...
