# %%
# your name and your student id
# %cat /etc/hostname # print out your computer id
# Out:
# e2256e5c47ae

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar07LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar07LC

# %%
# %ls
# Out:
# Mar07LC_Pre.html  Mar07LC_Pre.ipynb  us-cities-top-1k.csv  UtahCities.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar07LC'

# %%
import pandas as pd

# %%
df1 = pd.read_csv("us-cities-top-1k.csv")

# %%
df1 # print(df1) shortcut
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
c1 = df1["State"]=="Utah" # condition
c1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: State, Length: 1000, dtype: bool

# %%
df2 = df1[c1]
df2
# Out:
#                  City State  Population        lat         lon
# 31              Logan  Utah       48913  41.736980 -111.833836
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 285         Bountiful  Utah       43023  40.889390 -111.880771
# 381             Provo  Utah      116288  40.233844 -111.658534
# 434      Spanish Fork  Utah       36956  40.114955 -111.654923
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 466          Riverton  Utah       40921  40.521893 -111.939102
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 568            Layton  Utah       70790  41.060222 -111.971053
# 603            Murray  Utah       48612  40.666892 -111.887991
# 630             Sandy  Utah       90231  40.564978 -111.838973
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 676              Orem  Utah       91648  40.296898 -111.694648
# ...

# %%
df2.to_csv("UtahCities.csv",index=True)
# index=True save the row number
# index=False not saving the row number

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Spring2025/LC/Mar07LC'

# %%
# %ls
# Out:
# Mar07LC_Post.ipynb  Mar07LC_Pre.html  us-cities-top-1k.csv  UtahCities.csv

# %%
import pandas as pd# as alias

# %%
df1 = pd.read_csv("us-cities-top-1k.csv")
print(df1)
# data frame
# series
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1["City"]
# Out:
# 0         Marysville
# 1             Perris
# 2          Cleveland
# 3          Worcester
# 4           Columbia
#            ...
# 995    West New York
# 996          Everett
# 997           Linden
# 998        Asheville
# 999          Compton
# Name: City, Length: 1000, dtype: object

# %%
df2=df1[ ["City","Population"] ] # collection ["City","Pop"]
print(df2)
df2.to_csv("city_pop.csv",index=False)
# csv: comma
# Out:
#               City  Population
# 0       Marysville       63269
# 1           Perris       72326
# 2        Cleveland      390113
# 3        Worcester      182544
# 4         Columbia      133358
# ..             ...         ...
# 995  West New York       52122
# 996        Everett       42935
# 997         Linden       41301
# 998      Asheville       87236
# 999        Compton       97877
#
# [1000 rows x 2 columns]

# %%
# %ls
# Out:
# city_pop.csv  Mar07LC_Post.ipynb  Mar07LC_Pre.html  us-cities-top-1k.csv  UtahCities.csv

# %%
print(df1)# dataframe
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
s1 = df1.shape # collection
s1#
# Out:
# (1000, 5)

# %%
print(s1[0])
# Out:
# 1000

# %%
len(df1)#print(len(df1))
# Out:
# 1000

# %%
cols = df1.columns
print(cols) # warehouse, collection
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
print(cols[1])
# Out:
# State

# %%
# while:
# for:
l1 = [3,6, 10] #
for item in l1:
  print("repeat")
  print(item)
# Out:
# repeat
# 3
# repeat
# 6
# repeat
# 10

# %%
df1.columns # collection
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
for c in df1.columns:
  print(c)
  s1 = df1[c]
  s1.to_csv(f"{c}.csv",index=False)
# Out:
# City
# State
# Population
# lat
# lon

# %%
# %ls
# Out:
# City.csv      lat.csv  Mar07LC_Post.ipynb  Population.csv  us-cities-top-1k.csv
# city_pop.csv  lon.csv  Mar07LC_Pre.html    State.csv       UtahCities.csv

# %%
print(df1)
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
l2 = [2,3]
print(l2)

l3 = [2,3]*3
print(l3)

l4 = [3.14]*10
print(l4)
# Out:
# [2, 3]
# [2, 3, 2, 3, 2, 3]
# [3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14]

# %%
print(df1)
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1["C1"]=[3.14]*1000 # series
print(df1)
print(df1.columns)
df1.to_csv("newPop.csv",index=False)
# Out:
#               City           State  Population        lat         lon    C1
# 0       Marysville      Washington       63269  48.051764 -122.177082  3.14
# 1           Perris      California       72326  33.782519 -117.228648  3.14
# 2        Cleveland            Ohio      390113  41.499320  -81.694361  3.14
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293  3.14
# 4         Columbia  South Carolina      133358  34.000710  -81.034814  3.14
# ..             ...             ...         ...        ...         ...   ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306  3.14
# 996        Everett   Massachusetts       42935  42.408430  -71.053663  3.14
# 997         Linden      New Jersey       41301  40.622048  -74.244590  3.14
# 998      Asheville  North Carolina       87236  35.595058  -82.551487  3.14
# 999        Compton      California       97877  33.895849 -118.220071  3.14
#
# [1000 rows x 6 columns]
# ...

# %%
# %ls
# Out:
# City.csv      lat.csv  Mar07LC_Post.ipynb  newPop.csv      State.csv             UtahCities.csv
# city_pop.csv  lon.csv  Mar07LC_Pre.html    Population.csv  us-cities-top-1k.csv

# %%
print(df1)
# Out:
#               City           State  Population        lat         lon    C1
# 0       Marysville      Washington       63269  48.051764 -122.177082  3.14
# 1           Perris      California       72326  33.782519 -117.228648  3.14
# 2        Cleveland            Ohio      390113  41.499320  -81.694361  3.14
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293  3.14
# 4         Columbia  South Carolina      133358  34.000710  -81.034814  3.14
# ..             ...             ...         ...        ...         ...   ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306  3.14
# 996        Everett   Massachusetts       42935  42.408430  -71.053663  3.14
# 997         Linden      New Jersey       41301  40.622048  -74.244590  3.14
# 998      Asheville  North Carolina       87236  35.595058  -82.551487  3.14
# 999        Compton      California       97877  33.895849 -118.220071  3.14
#
# [1000 rows x 6 columns]

# %%
df1["C2"]=df1["City"]
df1#print(df1)
# Out:
#               City           State  Population        lat         lon    C1  \
# 0       Marysville      Washington       63269  48.051764 -122.177082  3.14
# 1           Perris      California       72326  33.782519 -117.228648  3.14
# 2        Cleveland            Ohio      390113  41.499320  -81.694361  3.14
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293  3.14
# 4         Columbia  South Carolina      133358  34.000710  -81.034814  3.14
# ..             ...             ...         ...        ...         ...   ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306  3.14
# 996        Everett   Massachusetts       42935  42.408430  -71.053663  3.14
# 997         Linden      New Jersey       41301  40.622048  -74.244590  3.14
# 998      Asheville  North Carolina       87236  35.595058  -82.551487  3.14
# 999        Compton      California       97877  33.895849 -118.220071  3.14
#
#                 C2
# 0       Marysville
# ...

# %%
df1["NPop"]=df1["Population"]*1.1

# %%
df1
# Out:
#               City           State  Population        lat         lon    C1  \
# 0       Marysville      Washington       63269  48.051764 -122.177082  3.14
# 1           Perris      California       72326  33.782519 -117.228648  3.14
# 2        Cleveland            Ohio      390113  41.499320  -81.694361  3.14
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293  3.14
# 4         Columbia  South Carolina      133358  34.000710  -81.034814  3.14
# ..             ...             ...         ...        ...         ...   ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306  3.14
# 996        Everett   Massachusetts       42935  42.408430  -71.053663  3.14
# 997         Linden      New Jersey       41301  40.622048  -74.244590  3.14
# 998      Asheville  North Carolina       87236  35.595058  -82.551487  3.14
# 999        Compton      California       97877  33.895849 -118.220071  3.14
#
#                 C2      NPop
# ...

# %%
df1.to_csv("newdata.csv",index=True)

# %%
# %ls
# Out:
# City.csv      lat.csv  Mar07LC_Post.ipynb  newdata.csv  Population.csv  us-cities-top-1k.csv
# city_pop.csv  lon.csv  Mar07LC_Pre.html    newPop.csv   State.csv       UtahCities.csv

# %%
# %%shell
# jupyter nbconvert "Mar07LC_Post.ipynb" --to html
# Out:
# [NbConvertApp] Converting notebook Mar07LC_Post.ipynb to html
# [NbConvertApp] Writing 361689 bytes to Mar07LC_Post.html
