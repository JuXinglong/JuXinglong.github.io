# %%
print("Please input your name: ")
n = input() # n is a string
print("Please input your age: ")
ageStr = input() # ageStr is a string

ageInt = int(ageStr)# convert string to int

b1 = ageInt > 18 # b1 is a bool True or false
print(b1)

if ageInt>18:
  print("My age is " + str(ageInt))
  print("I am an adult now")
else:
  print("My age is " + str(ageInt)) # str() convert int to string
  print("I am not an adult.")
# Out:
# Please input your name:
# Your real name
# Please input your age:
# 20
# True
# My age is 20
# I am an adult now

# %%
# + - / * ** // % arithmetic only for numbers
# number: int 3 -3 0 1
# float (double): 3.0 3.2 -3.2 0.0
print(3**2)
print(32/3)

print(32//3)# int division
print(32%3) # reminder

print(2.0*3)
# Out:
# 9
# 10.666666666666666
# 10
# 2
# 6.0

# %%
# strings
str1="120.8"
# str: reserved key words
#
# rules:
agestr = "19" #string

print(agestr)
# bool
# Out:
# 19

# %%
print(str1+1.2) # print +
# print() function call
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-12d83dc4a3f2> in <cell line: 0>()
# ----> 1 print(str1+1.2) # print
#       2 # print() function call
#
# TypeError: can only concatenate str (not "float") to str

# %%
str1 = 19 # assignment
print(str1+1.2)
# Out:
# 20.2

# %%
# + : concatenate
str1 = "Tom is " + "19 years old" + "."
print(str1)
# Out:
# Tom is 19 years old.

# %%
str1 = "19"+"2.0" # assignment
print(str1)
# Out:
# 192.0

# %%
# built in functions
# str():  str() converter
# int(): int()
# float(): float("12.3")
# len(): len("12.3")
str1 = "192.0"
v1 = len(str1) + 1# call
print(v1)
# Out:
# 6

# %%
str1 = "12.3"
print( float(str1)+2  )
# Out:
# 14.3
