# %%
# your name and your student id
# list
#     0  1  2  3
l1 = [20,30,60,40] # l1 is a warehouse
# inside l1, there are 4 items.
print(l1)
# get the first item
item = l1[3] # get one single item in a warehouse l1
print(item)
# Out:
# [20, 30, 60, 40]
# 40

# %%
# dictionary
# warehouse
# dict vs list: label 0 1 2
# you need to specify the label for each item in the warehouse
d1 = {}
print(d1)

d2 = {"item1":20,"i2":30}
print(d2)

n = len(d2)
print(n)

item = d2["item1"]
print(item)

d2["item3"]=60
print(d2)
# Out:
# {}
# {'item1': 20, 'i2': 30}
# 2
# 20
# {'item1': 20, 'i2': 30, 'item3': 60}

# %%
# if else (conditional) statement
# assignment
# function
# simple vs complex

# 3 format
print("Input a grade: ")
gStr=input()# RAM
# float (double)
gDbl=float(gStr)

# format condition
if gDbl>90:
  print("The grade is great 90")
  print("congrats")
# Out:
# Input a grade:
# 91
# The grade is great 90
# congrats
