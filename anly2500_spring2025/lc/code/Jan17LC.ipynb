# %%
print("Your real name here")
print('Your student id here')
# Out:
# Your real name here
# Your student id here

# %%
print("""Please input your name: """) # triple ' or "
n = input()

s = "Hello, " + n
print(s)
# Out:
# Please input your name:
# Tom
# Hello, Tom

# %%
# comment
# data scientist, MIS, business analytics
#
# RAM and CPU
# RAM:
# CPU: expression
# variables ram
#
# 1. letter number _
# 2. letter _ (could not start with a number)

# = assignment operator
#
r1 = 2 + 4 # code, statement, assignment

print(r1) #
print(r1)
# print function (name)
# print() parameters ingredients

# datatypes roomtype
# int whole number -1 3 0 (4B)
# float double: 1.2 (8B)
r2 = 3*2 #
print(r2)# function call
print(r2)

r3 = 8/2 # / divide
print(r3)

r4 = 4.99//1 # integer division
print(r4)

r5 = 11%3 #
print(r5)
# Out:
# 6
# 6
# 6
# 6
# 4.0
# 4.0
# 2

# %%
r1 = 3**3 #
print(r1)
# Out:
# 27

# %%
# boolean bool True False
b1 = True # 1B
