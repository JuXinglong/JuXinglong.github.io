# %%
# ctrl s
# variable
# naming rules
# letter number _
# first char letter or _ (not a number)
# variable: RAM
# datatypes: room type in the hotel (different size)
# int: 4 B, 1 2 -1 0 -10
# float: 136.60 186.6, 8 B 126.6 : 8B  126.612111411541: 8B
# string: a pair of "" '' """""" ''''''  "Tom" '126.612111411541' # "" 5B 16B
# bool: True False 1 0

# age
# varaible name
# label
age_1 = 20 + 1 # = assignment, one line of code, statement
# expression
# two steps
# step 1: execute the right hand side (expression)
# step 2: store the result into a variable (RAM)

# 3 hard topics in programming
# 1 GB =  1024 MB = 1024X1024 B

# age_1: is the room card
# positive ingeter starts from 1, 2, , address
print(age_1) # second hard topic
print( id(age_1)  )
# Out:
# 21
# 133450680648560

# %%
# arithmetic operators
# + - * / % //
bal  =   100 #
bal = 100 * 1.1 #
bal = 6/2
bal = 6.6-2
# // : integer division
bal = 10//3
# % reminder
bal = 10%3

bal = 4%2+1
bal = 5%2
# **:
bal = 2**3

print(bal) #
# Out:
# 8

# %%
# comparison operator
b1 = True#
b1= False
# comparison operator: result in Boolean (bool,True/False)
# > < <= >= ==  !=
b1 = 3<2 #
b1 = 10>2
b1 = 3>=3 # greater than or equal 2
# == check equality
b1=6==5 #
b1 = 3==3 #

# != not equal to
b1 = 3!=4 #
b1 = 3!=3

print(b1)
# Out:
# False

# %%
age2 = 20
age2 = age2 + 1 #
age2=1000
age2 = age2*1.1
print(age2)
# Out:
# 1100.0
