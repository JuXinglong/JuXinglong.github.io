# %%
print("Week 3 lecture 2 on September 12")
# F11
# Out:
# Week 3 lecture 2 on September 12

# %%
# Cloud computing
# we buy what we only need (only get necessary resources)
# computer hardware, pay for waht we need
#
# Windows
# Mac IOS
# Linux (most)
#
# %cat /etc/*release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# %ls
# Out:
# sample_data/

# %%
# %ls
# Out:
# 'Colab Notebooks'/

# %%
# %pwd
# Out:
# '/content/drive/MyDrive'

# %%
# %cd "MyDrive"
# Out:
# /content/drive/MyDrive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY6200Fall2024/LC"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY6200Fall2024/LC

# %%
# %ls
# Out:
# W1_1Python.ipynb  W2_1.ipynb    W3_L2_Python.ipynb
# W1_2Python.ipynb  W2_LC2.ipynb  W3_Sep10_python.ipynb

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY6200Fall2024/LC'

# %%
# ipynb: interactive Python Notebook
# py
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY6200Fall2024/LC'

# %%
print(age1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-43b101c817ae> in <cell line: 1>()
# ----> 1 print(age1)
#
# NameError: name 'age1' is not defined

# %%
print(w1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-7b3f1cf48a9b> in <cell line: 1>()
# ----> 1 print(w1)
#
# NameError: name 'w1' is not defined

# %%
# module library
import mylib

# %%
print(mylib.age1)
# .
print(mylib.w1)
# Out:
# 20
# 126.6

# %%
import mylib as m

# %%
print(m.age1)
print(m.w1)
# Out:
# 20
# 126.6

# %%
# dictionary
     #0 1 2 3
l1 = [5,6,9,10]

# %%
print(l1[2])
# Out:
# 9

# %%
d1 = {"first number":5,"second":6,"third":9,"forth":10  }

# %%
d1["second"]
# Out:
# 6

# %%
print(d1)
# Out:
# {'first number': 5, 'second': 6, 'third': 9, 'forth': 10}

# %%
d1["fifth"] = 20

# %%
print(d1)
# Out:
# {'first number': 5, 'second': 6, 'third': 9, 'forth': 10, 'fifth': 20}

# %%
#
gl = [60,70,80]
d2={"grade":80}
print(d2["grade"])
# Out:
# 80

# %%
nl = [{"grade":x} for x in gl]
nl
# Out:
# [{'grade': 60}, {'grade': 70}, {'grade': 80}]

# %%
# strings
str1 = "" # '' "" ''' '''   """""""
str1= "Tom"
print(str1)
# Out:
# Tom

# %%
print(  len(str1)  )
# Out:
# 3

# %%
# escape sequence (special char) \t \n
str2 = "T\no\tm"
print(len(str2))
print(str2)
# Out:
# 5
# T
# o	m

# %%
# string interpolation
age1 = 20
w1= 126.6
g1= 96.6/100

# %%
str3 = f"The age is {age1}.\nThe weight is {w1:.3f}.\nThe grade is {g1:.4%}"
print(str3)
# Out:
# The age is 20.
# The weight is 126.600.
# The grade is 96.6000%

# %%
str4 = "This is ANLY 6200"

# %%
print(str4[1])
# Out:
# h

# %%
print(str4[1:5]) # shift enter
# Out:
# his

# %%
print(str4)
# Out:
# This is ANLY 6200

# %%
b1 = "Tom" in str4 #
print(b1)
# Out:
# False

# %%
str4
# Out:
# 'This is ANLY 6200'

# %%
str5 = str4.upper()
print(str5)
print(str4)
# Out:
# THIS IS ANLY 6200
# This is ANLY 6200

# %%
b2 = str4.isupper()
print(b2)
# Out:
# False

# %%
# list
l1 = [ 2,6,4,3]
print(l1)
# Out:
# [2, 6, 4, 3]

# %%
# random choice() shuffle()
import random

# %%
item = random.choice(l1)
print(item)
# Out:
# 6

# %%
random.shuffle(l1)
print(l1)
# Out:
# [6, 4, 3, 2]

# %%
# sort()
l1.sort(reverse=True)
print(l1)
# Out:
# [6, 4, 3, 2]

# %%
l1 = [ 2,6,4,3]
print(l1)
# Out:
# [2, 6, 4, 3]

# %%
l1.reverse()
print(l1)
# Out:
# [3, 4, 6, 2]

# %%
l2 = l1[::-1]
print(l2)
# Out:
# [2, 6, 4, 3]

# %%
l1 = [ 2,6,4,3]
print(l1)
# Out:
# [2, 6, 4, 3]

# %%
l2= [str(x) for x in l1]
str1 = "###".join(l2)
print(str1)
# Out:
# 2###6###4###3

# %%
# dict
stu1 = {"name":"Tom","age":20,"weight":130.6}
print(stu1)
# Out:
# {'name': 'Tom', 'age': 20, 'weight': 130.6}

# %%
print( stu1["weight"]  )
# Out:
# 130.6

# %%
# label, keys
# values
labels = stu1.keys()
print(labels)
# Out:
# dict_keys(['name', 'age', 'weight'])

# %%
values= stu1.values()
print(values)
# Out:
# dict_values(['Tom', 20, 130.6])

# %%
# membership : in, not in
b1 = "grade" in stu1.keys() #
print(b1)
# Out:
# False

# %%
# functions
# what is a function: machine
# function call:
def fun1(i1,i2):# addition
  #function body
  r = i1+i2
  return r

# %%
# fun1
#
r1 = fun1(i2=2,i1=3) #
r1 = fun1(2,3)
print(r1)
# Out:
# 5

# %%
# for
for i in list(range(10)):
  # loop body
  print("hello")
  print("Hi")
  print(i)
# Out:
# hello
# Hi
# 0
# hello
# Hi
# 1
# hello
# Hi
# 2
# hello
# Hi
# 3
# hello
# Hi
# 4
# hello
# Hi
# 5
# hello
# Hi
# 6
# hello
# Hi
# 7
# hello
# Hi
# 8
# hello
# Hi
# 9

# %%
l1 = list( range(1,100+1)  )
for a in list(range(5)):
  r = random.choice(l1)
  print(r)
# Out:
# 63
# 68
# 80
# 10
# 48

# %%
# while loop
i=1
while i<10:
  # loop body
  #print(i)
  r = random.choice(l1)
  print(r)
  i= i + 1 #
# Out:
# 58
# 54
# 96
# 59
# 71
# 9
# 21
# 20
# 91
