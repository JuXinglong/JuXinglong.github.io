# %%
print("ANLY 6200")
print("This is my first python code")
# Out:
# ANLY 6200
# This is my first python code

# %%
# Python Basics
# Python is a programming language.
# Ruby, Java, C++, GO, R, C#, C, Basic
# language, machine, computer
# we use programming languages to use computer resources
# two main resources:
# CPU: calculation
# RAM: (computer moemory, not hard drive) store the data

# syntax
# code vs comments
print(2+3) # command, one line of code, statement
# comments: not codes
# Out:
# 5

# %% [markdown]
# **print(2+10)**

# %%
# Variables
# data stored RAM:
# hotel: different kinds of rooms
# public storage places:
# datatypes in Python: int float bool string

p1 = 20 #
p2 = 3 +  5# CPU
# p1 variable name
# = assignment operator
# expression
# step 1: right hand side
# step 2: store it into a RAM space

print(p2)
# Out:
# 8
