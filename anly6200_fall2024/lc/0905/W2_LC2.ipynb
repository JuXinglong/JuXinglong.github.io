# %%
# logical operators (boolean operators)
# and or not
# and: true and true is true login
# or: only false or false is false
# not: not True: Flase, not False: True
b1 = not (3>2) #

r1 = 2*(3+6)

print(b1)
print(r1)
# Out:
# False
# 18

# %%
# if else (conditional statement)
g = 86
if g>85:
  print("Congats!")
  print("Seoncond line")
   # print("Third line")

print("This is the next line of if else")
# Out:
# Congats!
# Seoncond line
# This is the next line of if else

# %%
# if else
age1 = 5
if (age1>70) or (age1<6):
  print("You get the discount")
  print("congrats!")
else:
  print("You do not get the discout")
  print("")

print("the line after if else")
# Out:
# You do not get the discout
#
# the line after if else

# %%
# list dictionary (data structure, collections)
age1= 20 # integer
age2 = 21

# list
ageList = [19,20,18,22] # []

print(ageList)
# Out:
# [19, 20, 18, 22]
