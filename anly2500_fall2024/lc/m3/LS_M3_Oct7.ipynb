# %%
# Operating system: Linux
# free
# linux commands:
# ls:
# pwd
# cd:

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/LSM3_Oct7'

# %%
# %ls
# Out:
# us-cities-top-1k.csv

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/LSM3_Oct7"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/LSM3_Oct7

# %%
# module: some python code in antoher file
import pandas as pd

# %%
df1 = pd.read_csv("us-cities-top-1k.csv") # function
# df1: DataFrame
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1["City"] # Series
# Out:
# 0         Marysville
# 1             Perris
# 2          Cleveland
# 3          Worcester
# 4           Columbia
#            ...
# 995    West New York
# 996          Everett
# 997           Linden
# 998        Asheville
# 999          Compton
# Name: City, Length: 1000, dtype: object

# %%
df1.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
df1[["City","Population"]]
# Out:
#               City  Population
# 0       Marysville       63269
# 1           Perris       72326
# 2        Cleveland      390113
# 3        Worcester      182544
# 4         Columbia      133358
# ..             ...         ...
# 995  West New York       52122
# 996        Everett       42935
# 997         Linden       41301
# 998      Asheville       87236
# 999        Compton       97877
#
# [1000 rows x 2 columns]

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       10000  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
id(df1)
# Out:
# 140187695829856

# %%
df2 = df1 # assignment

# %%
id(df2)
# Out:
# 140187695829856

# %%
df1.iloc[1,2]=10000

# %%
df1.iloc[1,2]
# Out:
# 10000

# %%
df2.iloc[1,2]
# Out:
# 10000

# %%
# copy()
df2
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       10000  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df3 = df2.copy() #
df3
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       10000  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df3.iloc[1,2] = 20000

# %%
df3
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       20000  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       10000  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
# groupby() # divide the dataframe into smaller ones (dataframe)
gps = df3.groupby(by=["State"]) #

# %%
gps.groups.keys()
# Out:
# dict_keys(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'])

# %%
len( gps.groups.keys()  )
# Out:
# 51

# %%
df4 = gps.get_group("Utah") # dataframe
# Out:
# <ipython-input-38-18c58606c065>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   df4 = gps.get_group("Utah") # dataframe

# %%
df4.to_csv("utah_cities.csv", index=False)

# %%
df4.head(3)
# Out:
#              City State  Population       lat         lon
# 31          Logan  Utah       48913  41.73698 -111.833836
# 193  South Jordan  Utah       59366  40.56217 -111.929658
# 285     Bountiful  Utah       43023  40.88939 -111.880771

# %%
df4["Population"].mean()
# Out:
# 75819.42105263157

# %%
df5 = gps.get_group("Texas")
df5
# Out:
# <ipython-input-46-21c080896380>:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   df5 = gps.get_group("Texas")
#                      City  State  Population        lat         lon
# 20                Lubbock  Texas      239538  33.577863 -101.855166
# 28                Rowlett  Texas       58043  32.902902  -96.563880
# 38   North Richland Hills  Texas       67317  32.834295  -97.228903
# 59                 Dallas  Texas     1257676  32.776664  -96.796988
# 114             Texarkana  Texas       37442  33.425125  -94.047688
# ..                    ...    ...         ...        ...         ...
# 921             Arlington  Texas      379577  32.735687  -97.108066
# 922            Lewisville  Texas      101074  33.046233  -96.994174
# 963           League City  Texas       90983  29.507454  -95.094930
# ...

# %%
df5["Population"].sum()
# Out:
# 14836230

# %%
gps["Population"].max()
# Out:
# State
# Alabama                  212113
# Alaska                   300950
# Arizona                 1513367
# Arkansas                 197357
# California              3884307
# Colorado                 649495
# Connecticut              147216
# Delaware                  71525
# District of Columbia     646449
# Florida                  842583
# Georgia                  447841
# Hawaii                   347884
# Idaho                    214237
# Illinois                2718782
# Indiana                  843393
# Iowa                     207510
# Kansas                   386552
# Kentucky                 609893
# Louisiana                378715
# Maine                     66318
# Maryland                 622104
# Massachusetts            645966
# Michigan                 688701
# Minnesota                400070
# Mississippi              172638
# Missouri                 467007
# Montana                  109059
# Nebraska                 434353
# Nevada                   603488
# ...

# %%
df4.sort_values(by=["Population"],ascending=[False])
# Out:
#                  City State  Population        lat         lon
# 964    Salt Lake City  Utah      191180  40.760779 -111.891047
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 381             Provo  Utah      116288  40.233844 -111.658534
# 955       West Jordan  Utah      110077  40.609670 -111.939103
# 676              Orem  Utah       91648  40.296898 -111.694648
# 630             Sandy  Utah       90231  40.564978 -111.838973
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 856        St. George  Utah       76817  37.096528 -113.568416
# 568            Layton  Utah       70790  41.060222 -111.971053
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 31              Logan  Utah       48913  41.736980 -111.833836
# 603            Murray  Utah       48612  40.666892 -111.887991
# ...

# %%
df6 = df5.sort_values(by=["Population"],ascending=[False])

# %%
df6
# Out:
#             City  State  Population        lat        lon
# 646      Houston  Texas     2195914  29.760427 -95.369803
# 153  San Antonio  Texas     1409019  29.424122 -98.493628
# 59        Dallas  Texas     1257676  32.776664 -96.796988
# 249       Austin  Texas      885400  30.267153 -97.743061
# 895   Fort Worth  Texas      792727  32.755488 -97.330766
# ..           ...    ...         ...        ...        ...
# 824        Hurst  Texas       38448  32.823462 -97.170568
# 325    Lancaster  Texas       38071  32.592080 -96.756108
# 810  Friendswood  Texas       37587  29.529400 -95.201045
# 114    Texarkana  Texas       37442  33.425125 -94.047688
# 346      Weslaco  Texas       37093  26.159519 -97.990837
#
# [83 rows x 5 columns]

# %%
df6.to_csv("Texas.csv",index=False)

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       10000  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
gps.count()
# Out:
#                       City  Population  lat  lon
# State
# Alabama                 12          12   12   12
# Alaska                   1           1    1    1
# Arizona                 25          25   25   25
# Arkansas                10          10   10   10
# California             212         212  212  212
# Colorado                21          21   21   21
# Connecticut             15          15   15   15
# Delaware                 2           2    2    2
# District of Columbia     1           1    1    1
# Florida                 73          73   73   73
# Georgia                 18          18   18   18
# Hawaii                   1           1    1    1
# Idaho                    8           8    8    8
# Illinois                52          52   52   52
# Indiana                 21          21   21   21
# Iowa                    13          13   13   13
# Kansas                  11          11   11   11
# Kentucky                 5           5    5    5
# ...

# %%
df1["State"].value_counts()
# Out:
# State
# California              212
# Texas                    83
# Florida                  73
# Illinois                 52
# Massachusetts            36
# Ohio                     33
# Michigan                 31
# Washington               28
# Arizona                  25
# Minnesota                24
# New Jersey               22
# North Carolina           22
# Indiana                  21
# Colorado                 21
# Wisconsin                20
# Utah                     19
# Georgia                  18
# Tennessee                17
# New York                 17
# Virginia                 17
# Missouri                 16
# Connecticut              15
# Oregon                   14
# Pennsylvania             13
# Iowa                     13
# Alabama                  12
# South Carolina           12
# Kansas                   11
# Oklahoma                 11
# Arkansas                 10
# Louisiana                 9
# Idaho                     8
# New Mexico                7
# ...

# %%
df4
# Out:
#                  City State  Population        lat         lon
# 31              Logan  Utah       48913  41.736980 -111.833836
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 285         Bountiful  Utah       43023  40.889390 -111.880771
# 381             Provo  Utah      116288  40.233844 -111.658534
# 434      Spanish Fork  Utah       36956  40.114955 -111.654923
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 466          Riverton  Utah       40921  40.521893 -111.939102
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 568            Layton  Utah       70790  41.060222 -111.971053
# 603            Murray  Utah       48612  40.666892 -111.887991
# 630             Sandy  Utah       90231  40.564978 -111.838973
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 676              Orem  Utah       91648  40.296898 -111.694648
# ...

# %%
len(df4)
# Out:
# 19

# %%
df4.shape
# Out:
# (19, 5)

# %%
df7 = df4.copy()
df7
# Out:
#                  City State  Population        lat         lon
# 31              Logan  Utah       48913  41.736980 -111.833836
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 285         Bountiful  Utah       43023  40.889390 -111.880771
# 381             Provo  Utah      116288  40.233844 -111.658534
# 434      Spanish Fork  Utah       36956  40.114955 -111.654923
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 466          Riverton  Utah       40921  40.521893 -111.939102
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 568            Layton  Utah       70790  41.060222 -111.971053
# 603            Murray  Utah       48612  40.666892 -111.887991
# 630             Sandy  Utah       90231  40.564978 -111.838973
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 676              Orem  Utah       91648  40.296898 -111.694648
# ...

# %%
len(df7)
# Out:
# 21

# %%
df7.loc[1001]= ["New city","new state",10000,0,0]

# %%
df7
# Out:
#                    City      State  Population        lat         lon
#  31               Logan       Utah       48913  41.736980 -111.833836
#  193       South Jordan       Utah       59366  40.562170 -111.929658
#  285          Bountiful       Utah       43023  40.889390 -111.880771
#  381              Provo       Utah      116288  40.233844 -111.658534
#  434       Spanish Fork       Utah       36956  40.114955 -111.654923
#  440       Taylorsville       Utah       60519  40.667725 -111.938826
#  466           Riverton       Utah       40921  40.521893 -111.939102
#  500               Lehi       Utah       54382  40.391617 -111.850766
#  533              Ogden       Utah       84249  41.223000 -111.973830
#  568             Layton       Utah       70790  41.060222 -111.971053
#  603             Murray       Utah       48612  40.666892 -111.887991
#  630              Sandy       Utah       90231  40.564978 -111.838973
# ...

# %%
len(df7)
# Out:
# 21

# %%
df7.shape
# Out:
# (21, 5)

# %%
df7.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
df7["New Col1"]=[2]*21

# %%
df7["New Pop"] = df7["Population"]*1.03

# %%
df7["New Col2"]= df7["lat"] + df7["lon"]

# %%
df7
# Out:
#                    City      State  Population        lat         lon  \
#  31               Logan       Utah       48913  41.736980 -111.833836
#  193       South Jordan       Utah       59366  40.562170 -111.929658
#  285          Bountiful       Utah       43023  40.889390 -111.880771
#  381              Provo       Utah      116288  40.233844 -111.658534
#  434       Spanish Fork       Utah       36956  40.114955 -111.654923
#  440       Taylorsville       Utah       60519  40.667725 -111.938826
#  466           Riverton       Utah       40921  40.521893 -111.939102
#  500               Lehi       Utah       54382  40.391617 -111.850766
#  533              Ogden       Utah       84249  41.223000 -111.973830
#  568             Layton       Utah       70790  41.060222 -111.971053
#  603             Murray       Utah       48612  40.666892 -111.887991
#  630              Sandy       Utah       90231  40.564978 -111.838973
# ...

# %%
df7
# Out:
#                    City      State  Population        lat         lon  \
#  31               Logan       Utah       48913  41.736980 -111.833836
#  193       South Jordan       Utah       59366  40.562170 -111.929658
#  285          Bountiful       Utah       43023  40.889390 -111.880771
#  381              Provo       Utah      116288  40.233844 -111.658534
#  434       Spanish Fork       Utah       36956  40.114955 -111.654923
#  440       Taylorsville       Utah       60519  40.667725 -111.938826
#  466           Riverton       Utah       40921  40.521893 -111.939102
#  500               Lehi       Utah       54382  40.391617 -111.850766
#  533              Ogden       Utah       84249  41.223000 -111.973830
#  568             Layton       Utah       70790  41.060222 -111.971053
#  603             Murray       Utah       48612  40.666892 -111.887991
#  630              Sandy       Utah       90231  40.564978 -111.838973
# ...

# %%
len(df7)
# Out:
# 21

# %%
df7.shape
# Out:
# (21, 8)

# %%
# delete rows
df8=df7.drop([-1,737],axis=0) # axis =0

# %%
df8.shape
# Out:
# (19, 8)

# %%
df7
# Out:
#                    City      State  Population        lat         lon  \
#  31               Logan       Utah       48913  41.736980 -111.833836
#  193       South Jordan       Utah       59366  40.562170 -111.929658
#  285          Bountiful       Utah       43023  40.889390 -111.880771
#  381              Provo       Utah      116288  40.233844 -111.658534
#  434       Spanish Fork       Utah       36956  40.114955 -111.654923
#  440       Taylorsville       Utah       60519  40.667725 -111.938826
#  466           Riverton       Utah       40921  40.521893 -111.939102
#  500               Lehi       Utah       54382  40.391617 -111.850766
#  533              Ogden       Utah       84249  41.223000 -111.973830
#  568             Layton       Utah       70790  41.060222 -111.971053
#  603             Murray       Utah       48612  40.666892 -111.887991
#  630              Sandy       Utah       90231  40.564978 -111.838973
# ...

# %%
df7.shape
# Out:
# (21, 8)

# %%
df7.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon', 'New Col1', 'New Pop',
#        'New Col2'],
#       dtype='object')

# %%
df9 = df7.drop(["lon","New Col1"],axis = 1) # delete columns

# %%
df9
# Out:
#                    City      State  Population        lat    New Pop  \
#  31               Logan       Utah       48913  41.736980   50380.39
#  193       South Jordan       Utah       59366  40.562170   61146.98
#  285          Bountiful       Utah       43023  40.889390   44313.69
#  381              Provo       Utah      116288  40.233844  119776.64
#  434       Spanish Fork       Utah       36956  40.114955   38064.68
#  440       Taylorsville       Utah       60519  40.667725   62334.57
#  466           Riverton       Utah       40921  40.521893   42148.63
#  500               Lehi       Utah       54382  40.391617   56013.46
#  533              Ogden       Utah       84249  41.223000   86776.47
#  568             Layton       Utah       70790  41.060222   72913.70
#  603             Murray       Utah       48612  40.666892   50070.36
#  630              Sandy       Utah       90231  40.564978   92937.93
#  673   West Valley City       Utah      133579  40.691613  137586.37
# ...

# %%
pd.Series([10,20,30],index=["Tom","Kelly","Jack"],name="Age")
# Out:
# Tom      10
# Kelly    20
# Jack     30
# Name: Age, dtype: int64

# %%
d1 = {
    "Age":[10,20,30],
    "W":[120,130,126],
    "Grade":[96,86,76]
}

# %%
pd.DataFrame(d1,index=["Tom","Kelly","Jack"])
# Out:
#        Age    W  Grade
# Tom     10  120     96
# Kelly   20  130     86
# Jack    30  126     76

# %%
city_pop = pd.DataFrame(
    [
        [808976, "San Francisco", "California"],
        [8363710, "New York", "New-York"],
        [413201, "Miami", "Florida"],
        [2242193, "Houston", "Texas"]
    ], index=[3,4,5,6], columns=["population", "city", "state"])

city_loc = pd.DataFrame(
    [
        ["CA", "San Francisco", 37.781334, -122.416728],
        ["NY", "New York", 40.705649, -74.008344],
        ["FL", "Miami", 25.791100, -80.320733],
        ["OH", "Cleveland", 41.473508, -81.739791],
        ["UT", "Salt Lake City", 40.755851, -111.896657]
    ], columns=["state", "city", "lat", "lng"])

# %%
city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %%
city_loc
# Out:
#   state            city        lat         lng
# 0    CA   San Francisco  37.781334 -122.416728
# 1    NY        New York  40.705649  -74.008344
# 2    FL           Miami  25.791100  -80.320733
# 3    OH       Cleveland  41.473508  -81.739791
# 4    UT  Salt Lake City  40.755851 -111.896657

# %%
# contact() vertically combine
# merge() horizontally combine

# %%
#
df10 = pd.concat([city_pop,city_loc])

# %%
df10 # not a number
# Out:
#    population            city       state        lat         lng
# 3    808976.0   San Francisco  California        NaN         NaN
# 4   8363710.0        New York    New-York        NaN         NaN
# 5    413201.0           Miami     Florida        NaN         NaN
# 6   2242193.0         Houston       Texas        NaN         NaN
# 0         NaN   San Francisco          CA  37.781334 -122.416728
# 1         NaN        New York          NY  40.705649  -74.008344
# 2         NaN           Miami          FL  25.791100  -80.320733
# 3         NaN       Cleveland          OH  41.473508  -81.739791
# 4         NaN  Salt Lake City          UT  40.755851 -111.896657

# %%
city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %%
city_loc
# Out:
#   state            city        lat         lng
# 0    CA   San Francisco  37.781334 -122.416728
# 1    NY        New York  40.705649  -74.008344
# 2    FL           Miami  25.791100  -80.320733
# 3    OH       Cleveland  41.473508  -81.739791
# 4    UT  Salt Lake City  40.755851 -111.896657

# %%
# merge
pd.merge(left=city_pop,right=city_loc,left_on="city",right_on="city",how="outer") # inner outer left right
# inner: common
# Out:
#    population            city     state_x state_y        lat         lng
# 0         NaN       Cleveland         NaN      OH  41.473508  -81.739791
# 1   2242193.0         Houston       Texas     NaN        NaN         NaN
# 2    413201.0           Miami     Florida      FL  25.791100  -80.320733
# 3   8363710.0        New York    New-York      NY  40.705649  -74.008344
# 4         NaN  Salt Lake City         NaN      UT  40.755851 -111.896657
# 5    808976.0   San Francisco  California      CA  37.781334 -122.416728

# %%
df10
# Out:
#    population            city       state        lat         lng
# 3    808976.0   San Francisco  California        NaN         NaN
# 4   8363710.0        New York    New-York        NaN         NaN
# 5    413201.0           Miami     Florida        NaN         NaN
# 6   2242193.0         Houston       Texas        NaN         NaN
# 0         NaN   San Francisco          CA  37.781334 -122.416728
# 1         NaN        New York          NY  40.705649  -74.008344
# 2         NaN           Miami          FL  25.791100  -80.320733
# 3         NaN       Cleveland          OH  41.473508  -81.739791
# 4         NaN  Salt Lake City          UT  40.755851 -111.896657

# %%
df10.fillna(0)
# Out:
#    population            city       state        lat         lng
# 3    808976.0   San Francisco  California   0.000000    0.000000
# 4   8363710.0        New York    New-York   0.000000    0.000000
# 5    413201.0           Miami     Florida   0.000000    0.000000
# 6   2242193.0         Houston       Texas   0.000000    0.000000
# 0         0.0   San Francisco          CA  37.781334 -122.416728
# 1         0.0        New York          NY  40.705649  -74.008344
# 2         0.0           Miami          FL  25.791100  -80.320733
# 3         0.0       Cleveland          OH  41.473508  -81.739791
# 4         0.0  Salt Lake City          UT  40.755851 -111.896657

# %%
df10
# Out:
#    population            city       state        lat         lng
# 3    808976.0   San Francisco  California        NaN         NaN
# 4   8363710.0        New York    New-York        NaN         NaN
# 5    413201.0           Miami     Florida        NaN         NaN
# 6   2242193.0         Houston       Texas        NaN         NaN
# 0         NaN   San Francisco          CA  37.781334 -122.416728
# 1         NaN        New York          NY  40.705649  -74.008344
# 2         NaN           Miami          FL  25.791100  -80.320733
# 3         NaN       Cleveland          OH  41.473508  -81.739791
# 4         NaN  Salt Lake City          UT  40.755851 -111.896657

# %%
df10.dropna(axis=1)
# Out:
#              city       state
# 3   San Francisco  California
# 4        New York    New-York
# 5           Miami     Florida
# 6         Houston       Texas
# 0   San Francisco          CA
# 1        New York          NY
# 2           Miami          FL
# 3       Cleveland          OH
# 4  Salt Lake City          UT
