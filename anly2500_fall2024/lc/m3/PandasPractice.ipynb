# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LC/M3_Pandas_Practice'

# %%
# %ls
# Out:
# PandasPractice.ipynb  tipsM.csv

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LC/M3_Pandas_Practice"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LC/M3_Pandas_Practice

# %%
import pandas as pd

# %%
df = pd.read_csv("tipsM.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   2.0
# 1       10.34  1.66    Male     No  Sun  Dinner   3.0
# 2       21.01  3.50    Male     No  Sun  Dinner   3.0

# %%
df.tail(6)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  245 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        245 non-null    object
#  6   size        244 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  245.000000  244.000000  244.000000
# mean    19.746000    2.998279    2.569672
# std      8.906122    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.280000    2.000000    2.000000
# 50%     17.780000    2.900000    2.000000
# 75%     24.080000    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
df["total_bill"].sum()
# Out:
# 4837.77

# %%
df[["total_bill","tip"]].mean()
# Out:
# total_bill    19.746000
# tip            2.998279
# dtype: float64

# %%
df["time"].count()
# Out:
# 245

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=245, step=1)

# %%
df.shape
# Out:
# (245, 7)

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size          float64
# dtype: object

# %%
# indexing slicing
#1.
df["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# 244     NaN
# Name: tip, Length: 245, dtype: float64

# %%
#2
df[["tip","total_bill"]]
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# ..    ...         ...
# 240  2.00       27.18
# 241  2.00       22.67
# 242  1.75       17.82
# 243  3.00       18.78
# 244   NaN       10.00
#
# [245 rows x 2 columns]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
sr=df.iloc[1,:]
sr
# Out:
# total_bill     10.34
# tip             1.66
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size             3.0
# Name: 1, dtype: object

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
sr2 = df.iloc[[1],:]
sr2
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner   3.0

# %%
type(sr2)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[3:10+1,:]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 3        23.68  3.31    Male     No  Sun  Dinner   2.0
# 4        24.59  3.61  Female     No  Sun  Dinner   4.0
# 5        25.29  4.71    Male     No  Sun  Dinner   4.0
# 6         8.77  2.00    Male     No  Sun  Dinner   2.0
# 7        26.88  3.12    Male     No  Sun  Dinner   4.0
# 8        15.04  1.96    Male     No  Sun  Dinner   2.0
# 9        14.78  3.23    Male     No  Sun  Dinner   2.0
# 10       10.27  1.71    Male     No  Sun  Dinner   2.0

# %%
df.iloc[3:11,[1,5]]
# Out:
#      tip    time
# 3   3.31  Dinner
# 4   3.61  Dinner
# 5   4.71  Dinner
# 6   2.00  Dinner
# 7   3.12  Dinner
# 8   1.96  Dinner
# 9   3.23  Dinner
# 10  1.71  Dinner

# %%
# sort values()
df.sort_values(by=["tip","total_bill"],ascending=[True,True])
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 67         3.07   1.00  Female    Yes  Sat  Dinner   1.0
# 92         5.75   1.00  Female    Yes  Fri  Dinner   2.0
# 111        7.25   1.00  Female     No  Sat  Dinner   1.0
# 236       12.60   1.00    Male    Yes  Sat  Dinner   2.0
# 0         16.99   1.01  Female     No  Sun  Dinner   2.0
# ..          ...    ...     ...    ...  ...     ...   ...
# 59        48.27   6.73    Male     No  Sat  Dinner   4.0
# 23        39.42   7.58    Male     No  Sat  Dinner   4.0
# 212       48.33   9.00    Male     No  Sat  Dinner   4.0
# 170       50.81  10.00    Male    Yes  Sat  Dinner   3.0
# 244       10.00    NaN     NaN    NaN  NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
# count days
df["day"].value_counts() # series
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
# filtering
# 1
c1 = df["sex"]=="Male"
c1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 240    False
# 241     True
# 242     True
# 243    False
# 244    False
# Name: sex, Length: 245, dtype: bool

# %%
df[c1]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner   3.0
# 2         21.01  3.50  Male     No  Sun  Dinner   3.0
# 3         23.68  3.31  Male     No  Sun  Dinner   2.0
# 5         25.29  4.71  Male     No  Sun  Dinner   4.0
# 6          8.77  2.00  Male     No  Sun  Dinner   2.0
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner   2.0
# 237       32.83  1.17  Male    Yes  Sat  Dinner   2.0
# 239       29.03  5.92  Male     No  Sat  Dinner   3.0
# 241       22.67  2.00  Male    Yes  Sat  Dinner   2.0
# 242       17.82  1.75  Male     No  Sat  Dinner   2.0
#
# [157 rows x 7 columns]

# %%
#2
c2 = (df["tip"]>2)  & (df["total_bill"]<20)
c2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 240    False
# 241    False
# 242    False
# 243     True
# 244    False
# Length: 245, dtype: bool

# %%
df[c2]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 9         14.78  3.23    Male     No   Sun  Dinner   2.0
# 13        18.43  3.00    Male     No   Sun  Dinner   4.0
# 14        14.83  3.02  Female     No   Sun  Dinner   2.0
# 17        16.29  3.71    Male     No   Sun  Dinner   3.0
# 18        16.97  3.50  Female     No   Sun  Dinner   3.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 228       13.28  2.72    Male     No   Sat  Dinner   2.0
# 231       15.69  3.00    Male    Yes   Sat  Dinner   3.0
# 232       11.61  3.39    Male     No   Sat  Dinner   2.0
# 234       15.53  3.00    Male    Yes   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [77 rows x 7 columns]

# %%
#3
c3 = (df["tip"]>5) | (df["total_bill"]>40)
c3
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# Length: 245, dtype: bool

# %%
df[c3]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner   4.0
# 44        30.40   5.60    Male     No   Sun  Dinner   4.0
# 47        32.40   6.00    Male     No   Sun  Dinner   4.0
# 52        34.81   5.20  Female     No   Sun  Dinner   4.0
# 59        48.27   6.73    Male     No   Sat  Dinner   4.0
# 85        34.83   5.17  Female     No  Thur   Lunch   4.0
# 88        24.71   5.85    Male     No  Thur   Lunch   2.0
# 95        40.17   4.73    Male    Yes   Fri  Dinner   4.0
# 102       44.30   2.50  Female    Yes   Sat  Dinner   3.0
# 116       29.93   5.07    Male     No   Sun  Dinner   4.0
# 141       34.30   6.70    Male     No  Thur   Lunch   6.0
# 142       41.19   5.00    Male     No  Thur   Lunch   5.0
# 155       29.85   5.14  Female     No   Sun  Dinner   5.0
# 156       48.17   5.00    Male     No   Sun  Dinner   6.0
# 170       50.81  10.00    Male    Yes   Sat  Dinner   3.0
# ...

# %%
# 4
c4 = (df["tip"]>5) & (df["total_bill"]>40) & (df["sex"]=="Male")
df[c4]
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 59        48.27   6.73  Male     No  Sat  Dinner   4.0
# 170       50.81  10.00  Male    Yes  Sat  Dinner   3.0
# 212       48.33   9.00  Male     No  Sat  Dinner   4.0

# %%
# 5
c5 = (df["tip"]>5) & (df["total_bill"]>40) & (df["sex"]=="Male") & (df["time"]=="Dinner")
df[c5]
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 59        48.27   6.73  Male     No  Sat  Dinner   4.0
# 170       50.81  10.00  Male    Yes  Sat  Dinner   3.0
# 212       48.33   9.00  Male     No  Sat  Dinner   4.0

# %%
# groupby
# 1
gs1 = df.groupby(by=["sex"])

# %%
gs1.groups.keys()
# Out:
# dict_keys(['Female', 'Male'])

# %%
f_df=gs1.get_group("Female")
f_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# 11        35.26  5.00  Female     No   Sun  Dinner   4.0
# 14        14.83  3.02  Female     No   Sun  Dinner   2.0
# 16        10.33  1.67  Female     No   Sun  Dinner   3.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch   2.0
# 229       22.12  2.88  Female    Yes   Sat  Dinner   2.0
# 238       35.83  4.67  Female     No   Sat  Dinner   3.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [87 rows x 7 columns]

# %%
m_df=gs1.get_group("Male")
m_df
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner   3.0
# 2         21.01  3.50  Male     No  Sun  Dinner   3.0
# 3         23.68  3.31  Male     No  Sun  Dinner   2.0
# 5         25.29  4.71  Male     No  Sun  Dinner   4.0
# 6          8.77  2.00  Male     No  Sun  Dinner   2.0
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner   2.0
# 237       32.83  1.17  Male    Yes  Sat  Dinner   2.0
# 239       29.03  5.92  Male     No  Sat  Dinner   3.0
# 241       22.67  2.00  Male    Yes  Sat  Dinner   2.0
# 242       17.82  1.75  Male     No  Sat  Dinner   2.0
#
# [157 rows x 7 columns]

# %%
f_df.to_csv("Female.csv",index=False)

# %%
f_df["tip"].mean()
# Out:
# 2.8334482758620685

# %%
f_df[["tip","total_bill"]].mean()
# Out:
# tip            2.833448
# total_bill    18.056897
# dtype: float64

# %%
m_df["total_bill"].mean()
# Out:
# 20.744076433121016

# %%
m_df["tip"].mean()
# Out:
# 3.0896178343949043

# %%
m_df[["tip","total_bill"]].mean()
# Out:
# tip            3.089618
# total_bill    20.744076
# dtype: float64

# %%
# 2
gs2 = df.groupby(by=["day"])

# %%
gs2.groups.keys()
# Out:
# dict_keys(['Fri', 'Sat', 'Sun', 'Thur'])

# %%
sun_df=gs2.get_group("Sun")
sun_df
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner   2.0
# 1         10.34  1.66    Male     No  Sun  Dinner   3.0
# 2         21.01  3.50    Male     No  Sun  Dinner   3.0
# 3         23.68  3.31    Male     No  Sun  Dinner   2.0
# 4         24.59  3.61  Female     No  Sun  Dinner   4.0
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner   3.0
# 187       30.46  2.00    Male    Yes  Sun  Dinner   5.0
# 188       18.15  3.50  Female    Yes  Sun  Dinner   3.0
# 189       23.10  4.00    Male    Yes  Sun  Dinner   3.0
# 190       15.69  1.50    Male    Yes  Sun  Dinner   2.0
#
# [76 rows x 7 columns]

# %%
sat_df=gs2.get_group("Sat")
sat_df
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner   3.0
# 20        17.92  4.08    Male     No  Sat  Dinner   2.0
# 21        20.29  2.75  Female     No  Sat  Dinner   2.0
# 22        15.77  2.23  Female     No  Sat  Dinner   2.0
# 23        39.42  7.58    Male     No  Sat  Dinner   4.0
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner   3.0
# 239       29.03  5.92    Male     No  Sat  Dinner   3.0
# 240       27.18  2.00  Female    Yes  Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes  Sat  Dinner   2.0
# 242       17.82  1.75    Male     No  Sat  Dinner   2.0
#
# [87 rows x 7 columns]

# %%
sun_df[["tip","total_bill"]].mean()
# Out:
# tip            3.255132
# total_bill    21.410000
# dtype: float64

# %%
sat_df["tip"].mean()
# Out:
# 2.993103448275862

# %%
sat_df["total_bill"].mean()
# Out:
# 20.441379310344825

# %%
# add delete change
#1
df1 = df.copy()
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
df1.loc[245]=[100.8, 20.6, "Female", "No", "Sun", "Dinner", 3]
df1
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner   2.0
# 1         10.34   1.66    Male     No   Sun  Dinner   3.0
# 2         21.01   3.50    Male     No   Sun  Dinner   3.0
# 3         23.68   3.31    Male     No   Sun  Dinner   2.0
# 4         24.59   3.61  Female     No   Sun  Dinner   4.0
# ..          ...    ...     ...    ...   ...     ...   ...
# 241       22.67   2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82   1.75    Male     No   Sat  Dinner   2.0
# 243       18.78   3.00  Female     No  Thur  Dinner   2.0
# 244       10.00    NaN     NaN    NaN   NaN   Lunch   NaN
# 245      100.80  20.60  Female     No   Sun  Dinner   3.0
#
# [246 rows x 7 columns]

# %%
df1.iloc[245,1]=26.00
df1
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner   2.0
# 1         10.34   1.66    Male     No   Sun  Dinner   3.0
# 2         21.01   3.50    Male     No   Sun  Dinner   3.0
# 3         23.68   3.31    Male     No   Sun  Dinner   2.0
# 4         24.59   3.61  Female     No   Sun  Dinner   4.0
# ..          ...    ...     ...    ...   ...     ...   ...
# 241       22.67   2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82   1.75    Male     No   Sat  Dinner   2.0
# 243       18.78   3.00  Female     No  Thur  Dinner   2.0
# 244       10.00    NaN     NaN    NaN   NaN   Lunch   NaN
# 245      100.80  26.00  Female     No   Sun  Dinner   3.0
#
# [246 rows x 7 columns]

# %%
df2=df1.drop([1,2,3],axis=0)
df2
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner   2.0
# 4         24.59   3.61  Female     No   Sun  Dinner   4.0
# 5         25.29   4.71    Male     No   Sun  Dinner   4.0
# 6          8.77   2.00    Male     No   Sun  Dinner   2.0
# 7         26.88   3.12    Male     No   Sun  Dinner   4.0
# ..          ...    ...     ...    ...   ...     ...   ...
# 241       22.67   2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82   1.75    Male     No   Sat  Dinner   2.0
# 243       18.78   3.00  Female     No  Thur  Dinner   2.0
# 244       10.00    NaN     NaN    NaN   NaN   Lunch   NaN
# 245      100.80  26.00  Female     No   Sun  Dinner   3.0
#
# [243 rows x 7 columns]

# %%
df1
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner   2.0
# 1         10.34   1.66    Male     No   Sun  Dinner   3.0
# 2         21.01   3.50    Male     No   Sun  Dinner   3.0
# 3         23.68   3.31    Male     No   Sun  Dinner   2.0
# 4         24.59   3.61  Female     No   Sun  Dinner   4.0
# ..          ...    ...     ...    ...   ...     ...   ...
# 241       22.67   2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82   1.75    Male     No   Sat  Dinner   2.0
# 243       18.78   3.00  Female     No  Thur  Dinner   2.0
# 244       10.00    NaN     NaN    NaN   NaN   Lunch   NaN
# 245      100.80  26.00  Female     No   Sun  Dinner   3.0
#
# [246 rows x 7 columns]

# %%
df1["tax1"]=[1]*246
df1
# Out:
#      total_bill    tip     sex smoker   day    time  size  tax1
# 0         16.99   1.01  Female     No   Sun  Dinner   2.0     1
# 1         10.34   1.66    Male     No   Sun  Dinner   3.0     1
# 2         21.01   3.50    Male     No   Sun  Dinner   3.0     1
# 3         23.68   3.31    Male     No   Sun  Dinner   2.0     1
# 4         24.59   3.61  Female     No   Sun  Dinner   4.0     1
# ..          ...    ...     ...    ...   ...     ...   ...   ...
# 241       22.67   2.00    Male    Yes   Sat  Dinner   2.0     1
# 242       17.82   1.75    Male     No   Sat  Dinner   2.0     1
# 243       18.78   3.00  Female     No  Thur  Dinner   2.0     1
# 244       10.00    NaN     NaN    NaN   NaN   Lunch   NaN     1
# 245      100.80  26.00  Female     No   Sun  Dinner   3.0     1
#
# [246 rows x 8 columns]

# %%
df1["tax2"]=df1["total_bill"]*0.08
df1
# Out:
#      total_bill    tip     sex smoker   day    time  size  tax1    tax2
# 0         16.99   1.01  Female     No   Sun  Dinner   2.0     1  1.3592
# 1         10.34   1.66    Male     No   Sun  Dinner   3.0     1  0.8272
# 2         21.01   3.50    Male     No   Sun  Dinner   3.0     1  1.6808
# 3         23.68   3.31    Male     No   Sun  Dinner   2.0     1  1.8944
# 4         24.59   3.61  Female     No   Sun  Dinner   4.0     1  1.9672
# ..          ...    ...     ...    ...   ...     ...   ...   ...     ...
# 241       22.67   2.00    Male    Yes   Sat  Dinner   2.0     1  1.8136
# 242       17.82   1.75    Male     No   Sat  Dinner   2.0     1  1.4256
# 243       18.78   3.00  Female     No  Thur  Dinner   2.0     1  1.5024
# 244       10.00    NaN     NaN    NaN   NaN   Lunch   NaN     1  0.8000
# 245      100.80  26.00  Female     No   Sun  Dinner   3.0     1  8.0640
#
# [246 rows x 9 columns]

# %%
df1
# Out:
#      total_bill    tip     sex smoker   day    time  size  tax1    tax2
# 0         16.99   1.01  Female     No   Sun  Dinner   2.0     1  1.3592
# 1         10.34   1.66    Male     No   Sun  Dinner   3.0     1  0.8272
# 2         21.01   3.50    Male     No   Sun  Dinner   3.0     1  1.6808
# 3         23.68   3.31    Male     No   Sun  Dinner   2.0     1  1.8944
# 4         24.59   3.61  Female     No   Sun  Dinner   4.0     1  1.9672
# ..          ...    ...     ...    ...   ...     ...   ...   ...     ...
# 241       22.67   2.00    Male    Yes   Sat  Dinner   2.0     1  1.8136
# 242       17.82   1.75    Male     No   Sat  Dinner   2.0     1  1.4256
# 243       18.78   3.00  Female     No  Thur  Dinner   2.0     1  1.5024
# 244       10.00    NaN     NaN    NaN   NaN   Lunch   NaN     1  0.8000
# 245      100.80  26.00  Female     No   Sun  Dinner   3.0     1  8.0640
#
# [246 rows x 9 columns]

# %%
df3 = df1.drop(["sex","smoker"],axis=1)
df3
# Out:
#      total_bill    tip   day    time  size  tax1    tax2
# 0         16.99   1.01   Sun  Dinner   2.0     1  1.3592
# 1         10.34   1.66   Sun  Dinner   3.0     1  0.8272
# 2         21.01   3.50   Sun  Dinner   3.0     1  1.6808
# 3         23.68   3.31   Sun  Dinner   2.0     1  1.8944
# 4         24.59   3.61   Sun  Dinner   4.0     1  1.9672
# ..          ...    ...   ...     ...   ...   ...     ...
# 241       22.67   2.00   Sat  Dinner   2.0     1  1.8136
# 242       17.82   1.75   Sat  Dinner   2.0     1  1.4256
# 243       18.78   3.00  Thur  Dinner   2.0     1  1.5024
# 244       10.00    NaN   NaN   Lunch   NaN     1  0.8000
# 245      100.80  26.00   Sun  Dinner   3.0     1  8.0640
#
# [246 rows x 7 columns]

# %%
# missing values
df4 = df.copy()
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
df5=df4.fillna(-1)
df5
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00 -1.00      -1     -1    -1   Lunch  -1.0
#
# [245 rows x 7 columns]

# %%
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
df4.dropna(axis=0)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [244 rows x 7 columns]

# %%
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       10.00   NaN     NaN    NaN   NaN   Lunch   NaN
#
# [245 rows x 7 columns]

# %%
df4.dropna(axis=1)
# Out:
#      total_bill    time
# 0         16.99  Dinner
# 1         10.34  Dinner
# 2         21.01  Dinner
# 3         23.68  Dinner
# 4         24.59  Dinner
# ..          ...     ...
# 240       27.18  Dinner
# 241       22.67  Dinner
# 242       17.82  Dinner
# 243       18.78  Dinner
# 244       10.00   Lunch
#
# [245 rows x 2 columns]
