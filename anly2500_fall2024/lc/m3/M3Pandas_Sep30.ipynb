# %%
print("Pandas") # ctrl s
# Out:
# Pandas

# %%
# cloud computing
# beef 1.2 lbs (2.2 lbs) buy what you need
# laptop. (128GB 8Cores 1TB) (32GB, 3Cores 200GB) 1/4 Cut
# service: free version

# %%
# operating system:
# windows: not free
# MAC: not free
# Android: not free ()
# Linux: are free on servers ()
# google server: Linux ()

# %%
# linux commands (are not python codes)
# %cat /etc/*release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# ls: list all files and folders in the current folder
# cd: change folder
# pwd
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/LSM3Pandas'

# %%
# %ls
# Out:
# M3Pandas_Sep30.ipynb  us-cities-top-1k.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/LSM3Pandas"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/LSM3Pandas

# %%
# .
str1 = "Tom"
str1.lower() # belongs to
# Out:
# 'tom'

# %%
age1 = 20
age2 = 26
print(age1)
print(age2)
# Out:
# 20
# 26

# %%
#print(age1)
age1
age2
# Out:
# 26

# %%
import mylib as m

# %%
# ipynb#
# py
# module library:
print(m.num1)
print(m.num2)
# Out:
# 100
# 200

# %%
# numpy pandas
import pandas as pd

# %%
# %ls
# Out:
# M3Pandas_Sep30.ipynb  mylib.py  __pycache__/  us-cities-top-1k.csv

# %%
# Series
# DataFrame
# CSV: text file. comma seperated values
df1=pd.read_csv("us-cities-top-1k.csv")# dataframe

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head(6)
# Out:
#          City           State  Population        lat         lon
# 0  Marysville      Washington       63269  48.051764 -122.177082
# 1      Perris      California       72326  33.782519 -117.228648
# 2   Cleveland            Ohio      390113  41.499320  -81.694361
# 3   Worcester   Massachusetts      182544  42.262593  -71.802293
# 4    Columbia  South Carolina      133358  34.000710  -81.034814
# 5   Waterbury     Connecticut      109676  41.558153  -73.051496

# %%
df1.tail(3)
# Out:
#           City           State  Population        lat         lon
# 997     Linden      New Jersey       41301  40.622048  -74.244590
# 998  Asheville  North Carolina       87236  35.595058  -82.551487
# 999    Compton      California       97877  33.895849 -118.220071

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        1000 non-null   object
#  1   State       1000 non-null   object
#  2   Population  1000 non-null   int64
#  3   lat         1000 non-null   float64
#  4   lon         1000 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
df1.describe()
# Out:
#          Population          lat          lon
# count  1.000000e+03  1000.000000  1000.000000
# mean   1.311324e+05    37.338241   -96.483023
# std    3.416902e+05     5.279127    17.024468
# min    3.687700e+04    21.306944  -157.858333
# 25%    4.969775e+04    33.748627  -116.959608
# 50%    6.820700e+04    37.768557   -93.238834
# 75%    1.098850e+05    41.618357   -82.171804
# max    8.405837e+06    61.218056   -70.255326

# %%
df1.shape# tuple
# Out:
# (1000, 5)

# %%
df1.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df1.dtypes # int64 float64 (int2) int3 999
# Out:
# City           object
# State          object
# Population      int64
# lat           float64
# lon           float64
# dtype: object

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1.mean()#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-00fb6bfec183> in <cell line: 1>()
# ----> 1 df1.mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11333         **kwargs,
#   11334     ):
# > 11335         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336         if isinstance(result, Series):
#   11337             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11990         **kwargs,
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
#   11993             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994         )
#
# ...

# %%
type(df1["Population"])
# Out:
# pandas.core.series.Series

# %%
df1["Population"].mean()# max() min()
# Out:
# 131132.443

# %%
df1["lat"].max()
# Out:
# 61.2180556

# %%
s1 = df1["City"]
s1
# Out:
# 0         Marysville
# 1             Perris
# 2          Cleveland
# 3          Worcester
# 4           Columbia
#            ...
# 995    West New York
# 996          Everett
# 997           Linden
# 998        Asheville
# 999          Compton
# Name: City, Length: 1000, dtype: object

# %%
s1.to_csv("city1.csv",index=True)
s1.to_csv("city2.csv",index=False)

# %%
df3 = df1[["City","Population"]] # [] indexer inside[] list
df3
# Out:
#               City  Population
# 0       Marysville       63269
# 1           Perris       72326
# 2        Cleveland      390113
# 3        Worcester      182544
# 4         Columbia      133358
# ..             ...         ...
# 995  West New York       52122
# 996        Everett       42935
# 997         Linden       41301
# 998      Asheville       87236
# 999        Compton       97877
#
# [1000 rows x 2 columns]

# %%
df3.to_csv("d3.csv",index=False)

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1[["Population","lat"]].max() #
# Out:
# Population    8.405837e+06
# lat           6.121806e+01
# dtype: float64

# %%
# index
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
# index
df2=df1.set_index("City",drop=False)
df2
# Out:
#                         City           State  Population        lat  \
# City
# Marysville        Marysville      Washington       63269  48.051764
# Perris                Perris      California       72326  33.782519
# Cleveland          Cleveland            Ohio      390113  41.499320
# Worcester          Worcester   Massachusetts      182544  42.262593
# Columbia            Columbia  South Carolina      133358  34.000710
# ...                      ...             ...         ...        ...
# West New York  West New York      New Jersey       52122  40.787879
# Everett              Everett   Massachusetts       42935  42.408430
# Linden                Linden      New Jersey       41301  40.622048
# Asheville          Asheville  North Carolina       87236  35.595058
# Compton              Compton      California       97877  33.895849
#
#                       lon
# City
# Marysville    -122.177082
# Perris        -117.228648
# Cleveland      -81.694361
# Worcester      -71.802293
# ...

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df2
# Out:
#                         City           State  Population        lat  \
# City
# Marysville        Marysville      Washington       63269  48.051764
# Perris                Perris      California       72326  33.782519
# Cleveland          Cleveland            Ohio      390113  41.499320
# Worcester          Worcester   Massachusetts      182544  42.262593
# Columbia            Columbia  South Carolina      133358  34.000710
# ...                      ...             ...         ...        ...
# West New York  West New York      New Jersey       52122  40.787879
# Everett              Everett   Massachusetts       42935  42.408430
# Linden                Linden      New Jersey       41301  40.622048
# Asheville          Asheville  North Carolina       87236  35.595058
# Compton              Compton      California       97877  33.895849
#
#                       lon
# City
# Marysville    -122.177082
# Perris        -117.228648
# Cleveland      -81.694361
# Worcester      -71.802293
# ...

# %%
df2.loc[["Linden","Perris"],["lat","City"]]
# Out:
#               lat    City
# City
# Linden  40.622048  Linden
# Perris  33.782519  Perris

# %%
df4=df1.iloc[[3,2,4],[2,0]]
df4
# Out:
#    Population       City
# 3      182544  Worcester
# 2      390113  Cleveland
# 4      133358   Columbia

# %%
df4.to_csv("d6.csv",index=False)

# %%
# iloc: integer
# loc: by name

# %%
df1.iloc[1,2]
# Out:
# 72326

# %%
df2.loc['Perris','Population']
# Out:
# 72326

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1.loc[[997,1],["lat","City"]]
# Out:
#            lat    City
# 997  40.622048  Linden
# 1    33.782519  Perris

# %%
df1.loc[["Linden","Perris"],["lat","City"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-66ce14333bc0> in <cell line: 1>()
# ----> 1 df1.loc[["Linden","Perris"],["lat","City"]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1145             if self._is_scalar_access(key):
#    1146                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147             return self._getitem_tuple(key)
#    1148         else:
#    1149             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1335         # ugly hack for GH #836
#    1336         if self._multi_take_opportunity(tup):
# -> 1337             return self._multi_take(tup)
#    1338
#    1339         return self._getitem_tuple_same_dim(tup)
#
# ...
