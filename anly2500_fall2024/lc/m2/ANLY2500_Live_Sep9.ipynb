# %%
print("ANLY 2500 first live session") # ctrl s
# ipynb: interactive python notebook
# .py
# F11
# Out:
# ANLY 2500 first live session

# %%
# code cell
# Python Programming Language
# language: computer
# commands
# 1950s B (VB, QB), C/C++ C++++ C# (C#, C Sharp, MS)  Java (SUN 2000, 2010, Oracle) Python
# syntax
print( 2+3-9 ) # ctrl enter # shift enter
# Out:
# -4

# %%
# code vs comment
# code
# comment notes not code
print("Hello") # this is a comment
# print()
# print is function name, machine
# print(..) function call,

print(20+3)
# Out:
# Hello
# 23

# %%
# computer resources: CPU (calculation) & computer memory (RAM) store data
# hard drive vs (RAM)
# 1s RAM, 1000s hard drive
print( 1000/60 ) # minutes
# Out:
# 16.666666666666668

# %%
# =
# variables
# datatypes
# CPU (calculation) RAM (data)
print( 2+3 ) #expression 2+3*3/9
# Out:
# 5

# %%
# we use varaible to use the RAM
# variable is the room card
age1 = 26 # assignment (operation)
# age1 : the variable (name) room card
# = assignment operator (meaning =)
#
# two steps:
# step 1: exectue the right hand side
# step 2: store the result into the variable
print(age1)
# Out:
# 26

# %%
r1 = 2+3*3-6 # 5 * multiplcation / division
# =
# step 1:
# step 2:
print(r1)
# Out:
# 5

# %%
# data types
# single, two bed, suite room types
# datatypes vs room types
# better use the resource of RAM
# int: 0 1 2 3 -1 -3, size: 4B (Bytes)
# float (double, decimal): 12.3 99.6 size: 8B (Bytes)
# bool: boolean: True False ()
# string: '' "" ''' ''' """"""
print("Hello AM") #8B

# int
r2 = 2+3  #
print(r2)

t1 = type( r2 ) #
print(t1)
# Out:
# Hello AM
# 5
# <class 'int'>

# %%
# float
r3 = 2.3*2 # * multiplcation operator
print( type(r3)  )
print(r3)
# Out:
# <class 'float'>

# %%
# bool boolean (True False)
b1 = True

print(type(b1))
print(b1)
# Out:
# <class 'bool'>
# True

# %%
# string
name1 = "Tom" #
print(name1)

print(type(name1))

print( len(name1) ) # length
# Out:
# Tom
# <class 'str'>
# 3

# %%
# naming rules of variables
# 1. letter number _
# 2. first char in var can not be number (can be a letter _)

age1 = 19
_age1 = 26

#2age2=26

# %%
# ** raise power
# // integer division
# % reminder

r3 = 4**3
print(r3)
# Out:
# 64

# %%
# //
r4 = 17%5

print(r4)
# Out:
# 2
