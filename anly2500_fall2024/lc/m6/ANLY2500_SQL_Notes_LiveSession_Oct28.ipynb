# %% [markdown]
# ## Introduction to Databases, Primary Keys, and Foreign Keys
#
# #### What is a Database?
# A **database**  is an organized collection of data that is stored electronically and can be easily accessed, managed, and updated. In a database, data is typically organized into **tables** , where each table represents a specific entity, like "Customers" or "Products." Each table is made up of **columns**  (attributes) and **rows**  (records).For example, consider a table called **Customers** :
#
# | CustomerID | Name | Email |
# | --- | --- | --- |
# | 1 | Alice | alice@email.com |
# | 2 | Bob | bob@email.com |
#
# Each row represents a record, and each column represents a piece of information about that record.
#
# #### What is a Primary Key?
# A **primary key**  is a column or a set of columns in a database table that uniquely identifies each record in that table. It ensures that no two records in the table have the same primary key value, which guarantees uniqueness.In the **Customers**  table above, the **CustomerID**  field can be a primary key because each value in the column is unique for each customer. This allows the database to quickly identify, retrieve, and organize information for each customer.
# Characteristics of a Primary Key:
#
# 1. **Unique** : No two records can have the same primary key value.
#
# 2. **Non-null** : The primary key field cannot be left empty.
#
# 3. **Unchanging** : The value of the primary key should remain constant.
#
# #### What is a Foreign Key?
# A **foreign key**  is a column or set of columns in one table that refers to the **primary key**  of another table. The foreign key creates a relationship between two tables, enabling cross-referencing of data. It ensures referential integrity, meaning that the data is consistent across related tables.For example, consider a second table called **Orders** :
#
# | OrderID | OrderDate | CustomerID |
# | --- | --- | --- |
# | 101 | 2023-09-21 | 1 |
# | 102 | 2023-09-22 | 2 |
#
# In this case, the **CustomerID**  column in the **Orders**  table is a **foreign key**  that refers to the **CustomerID**  in the **Customers**  table. This creates a relationship between customers and their orders, where each order can be linked to a specific customer.
# Characteristics of a Foreign Key:
#
# 1. **Links Tables** : It connects rows in one table to rows in another.
#
# 2. **Referential Integrity** : It ensures that the value in the foreign key column exists in the primary key column of the related table.
#
# #### How Do Primary and Foreign Keys Work Together?
# Primary and foreign keys work together to define relationships between tables in a relational database. By connecting tables, they allow complex queries that span multiple tables. For instance, you can use the **CustomerID**  foreign key in the **Orders**  table to retrieve all orders placed by a specific customer.
# This relationship helps to keep the database organized, prevent duplication of data, and maintain data consistency.
#
# ### Summary
#
# - A **database**  organizes data into tables, each with rows and columns.
#
# - A **primary key**  uniquely identifies records in a table.
#
# - A **foreign key**  links two tables together by referring to the primary key of another table, establishing a relationship.
#
# - Together, primary and foreign keys ensure data integrity and enable powerful data queries across multiple tables.
#
# This forms the foundation of how relational databases function, enabling efficient data management, retrieval, and relationship building.

# %% [markdown]
# ## Syntax of Select

# %% [markdown]
# <img  width="800" src='data:image/svg+xml;base64,...'/>

# %% [markdown]
# 1. **Order of Clauses Is Set:**
#   - The order of SQL clauses is crucial. Changing the order will result in an error. SQL clauses must follow this strict order:
#     1. `SELECT`
#
#     2. `FROM`
#
#     3. `WHERE`
#
#     4. `GROUP BY`
#
#     5. `HAVING`
#
#     6. `ORDER BY`
# If you mix the order (e.g., placing `ORDER BY` before `GROUP BY`), the query will fail to execute.
#
# 2. **Capitalize Commands for Readability:**
#   - SQL commands are case-insensitive, meaning it doesn't matter if they are written in uppercase or lowercase. However, it is a good practice to **capitalize SQL commands**  (`SELECT`, `FROM`, `WHERE`, etc.) to improve readability and make the code more standardized.
#
# Example of readable SQL:
#
#
# ```sql
# SELECT name, age
# FROM students
# WHERE age > 18
# ORDER BY age DESC;
# ```
# Additionally, **indentation**  and writing each clause on a new line makes the query much more readable and easier to debug.

# %% [markdown]
# `WHERE` Clause in SQLThe `WHERE` clause is used to filter records in a SQL query based on certain conditions. It is essential in retrieving only the rows that meet specific criteria.
#
# **Basic Syntax of Select**
#
#
# ```sql
# SELECT column1, column2, ...
# FROM table_name
# WHERE condition;
# ```
# Common Operators for the `WHERE` Clause
#
# 1. **Comparison Operators:**
# - `=`: Equal to
#
# - `<>`: Not equal to (or `!=` in some databases)
#
# - `>`: Greater than
#
# - `<`: Less than
#
# - `>=`: Greater than or equal to
#
# - `<=`: Less than or equal to
#
# **Example:**
#
#
# ```sql
# SELECT *
# FROM employees
# WHERE salary > 50000;
# ```
#
# This query selects employees with a salary greater than 50,000.
# 2. **Logical Operators:**
# - `AND`: Combines multiple conditions; both must be true.
#
# - `OR`: Combines multiple conditions; either one must be true.
#
# - `NOT`: Negates a condition.
# Example with `AND` and `OR`:
#
# ```sql
# SELECT *
# FROM employees
# WHERE salary > 50000 AND department = 'IT';
# ```
#
# This retrieves IT department employees with a salary greater than 50,000.
#
#
# ```sql
# SELECT *
# FROM employees
# WHERE department = 'IT' OR department = 'HR';
# ```
#
# This selects employees who belong to either the IT or HR departments.
# Example with `NOT`:
#
# ```sql
# SELECT *
# FROM employees
# WHERE NOT department = 'HR';
# ```
#
# This selects all employees except those in the HR department.
#
#
# 3. **`BETWEEN`:**
# This operator is used to filter values within a specific range.
#
# **Example:**
#
#
# ```sql
# SELECT *
# FROM employees
# WHERE salary BETWEEN 30000 AND 60000;
# ```
#
# This query retrieves employees with salaries between 30,000 and 60,000.
#
# 4. **`IN`:** The `IN` operator allows filtering based on multiple values.
#
# **Example:**
#
#
# ```sql
# SELECT *
# FROM employees
# WHERE department IN ('IT', 'HR', 'Sales');
# ```
#
# This query retrieves employees from the IT, HR, or Sales departments.
#
# 5. **`LIKE`:** The `LIKE` operator is used to search for patterns in text columns, often with wildcards:
# - `%` matches any sequence of characters.
#
# - `_` matches a single character.
#
# **Example:**
#
#
# ```sql
# SELECT *
# FROM employees
# WHERE name LIKE 'J%';
# ```
#
# This retrieves employees whose name starts with "J."
#
# 6. **`NULL`:** The `IS NULL` and `IS NOT NULL` operators check for `NULL` values.
#
# **Example:**
#
#
# ```sql
# SELECT *
# FROM employees
# WHERE manager_id IS NULL;
# ```
#
# This query retrieves employees who do not have a manager.
#
#
# ---
#
#
# **Combining Multiple Conditions**
#
# You can combine different operators and conditions in a `WHERE` clause using logical operators (`AND`, `OR`, `NOT`).
#
# **Example:**
#
#
# ```sql
# SELECT *
# FROM employees
# WHERE department = 'Sales'
#   AND salary > 40000
#   AND hire_date BETWEEN '2020-01-01' AND '2022-12-31';
# ```
#
# This query retrieves Sales department employees hired between 2020 and 2022 with a salary greater than 40,000.

# %% [markdown]
# ### **Math/Numeric Functions in SQL**
#
#
# These functions are used to perform mathematical calculations on data in SQL. They are often applied to numeric columns in a database.
#
# 1. **`SUM()`** The `SUM()` function returns the total sum of a numeric column.
# ##### Syntax:
#
#
# ```sql
# SELECT SUM(column_name)
# FROM table_name;
# ```
#
# ##### Example:
#
#
# ```sql
# SELECT SUM(salary)
# FROM employees;
# ```
# This query returns the total sum of all salaries from the `employees` table.2.
#
# 2. **`AVG()`** The `AVG()` function calculates the average value of a numeric column.
# ##### Syntax:
#
#
# ```sql
# SELECT AVG(column_name)
# FROM table_name;
# ```
#
# ##### Example:
#
#
# ```sql
# SELECT AVG(salary)
# FROM employees;
# ```
#
# This query calculates the average salary of all employees.
# 3. **`MAX()`** The `MAX()` function returns the highest value in a numeric column.
# ##### Syntax:
#
#
# ```sql
# SELECT MAX(column_name)
# FROM table_name;
# ```
#
# ##### Example:
#
#
# ```sql
# SELECT MAX(salary)
# FROM employees;
# ```
# This query retrieves the highest salary from the `employees` table.
#
# 4. **`MIN()`** The `MIN()` function returns the lowest value in a numeric column.
# ##### Syntax:
#
#
# ```sql
# SELECT MIN(column_name)
# FROM table_name;
# ```
#
# ##### Example:
#
#
# ```sql
# SELECT MIN(salary)
# FROM employees;
# ```
# This query retrieves the lowest salary from the `employees` table.
#
# 5. **`COUNT()`** The `COUNT()` function returns the number of rows that match a specified condition. If no condition is specified, it counts all rows.
# ##### Syntax:
#
#
# ```sql
# SELECT COUNT(column_name)
# FROM table_name;
# ```
#
# ##### Example:
#
#
# ```sql
# SELECT COUNT(*)
# FROM employees;
# ```
#
# This query returns the total number of employees in the table.
# 6. **`ROUND()`** The `ROUND()` function rounds a numeric column to a specified number of decimal places.
# ##### Syntax:
#
#
# ```sql
# SELECT ROUND(column_name, decimal_places)
# FROM table_name;
# ```
#
# ##### Example:
#
#
# ```sql
# SELECT ROUND(salary, 2)
# FROM employees;
# ```
#
# This query rounds the salary to 2 decimal places.
#
#
# ---
#
#
# ### Example Query Combining Functions:
#
# Let's combine these functions in a query:
#
#
# ```sql
# SELECT department,
#        SUM(salary) AS total_salary,
#        AVG(salary) AS average_salary,
#        MAX(salary) AS highest_salary,
#        MIN(salary) AS lowest_salary,
#        COUNT(*) AS employee_count
# FROM employees
# GROUP BY department;
# ```
#
# This query returns the following for each department:
#
# - Total sum of salaries
#
# - Average salary
#
# - Highest and lowest salaries
#
# - The number of employees in each department

# %% [markdown]
# ### SQL Query Structure Tutorial
#
# SQL (Structured Query Language) is used to manage and manipulate relational databases. A typical SQL query follows a specific structure with different clauses that serve distinct purposes. Here's a breakdown of each part of a query, which aligns with the image structure:
# 1. `SELECT`The `SELECT` statement is used to specify the columns or expressions that you want to retrieve from a database table.
#
# Syntax:
#
#
# ```sql
# SELECT column1, column2, ...
# FROM table_name;
# ```
#
# Example:
#
#
# ```sql
# SELECT name, age FROM students;
# ```
# This query retrieves the `name` and `age` columns from the `students` table.
#
# 2. `FROM`The `FROM` clause specifies the table from which the data is retrieved.
#
# Syntax:
#
#
# ```sql
# FROM table_name;
# ```
#
# Example:
#
#
# ```sql
# SELECT name, age
# FROM students;
# ```
# Here, data is selected from the `students` table.
#
# 3. `WHERE`The `WHERE` clause filters the records based on specific conditions. Only the rows that meet the conditions will be included in the result set.
#
# Syntax:
#
#
# ```sql
# WHERE condition;
# ```
#
# Example:
#
#
# ```sql
# SELECT name, age
# FROM students
# WHERE age > 18;
# ```
# This query selects the `name` and `age` of students who are older than 18.
#
# 4. `GROUP BY`The `GROUP BY` clause is used to group rows that have the same values in specified columns. Often, this is used with aggregate functions (`COUNT()`, `SUM()`, `AVG()`, etc.).
#
# #### Syntax:
#
#
# ```sql
# GROUP BY column1, column2, ...;
# ```
#
# Example:
#
#
# ```sql
# SELECT department, COUNT(*)
# FROM employees
# GROUP BY department;
# ```
# This groups the employees by their `department` and counts the number of employees in each department.
#
# 5. `HAVING`The `HAVING` clause is used to filter records after the `GROUP BY` operation. It is similar to `WHERE`, but `WHERE` cannot be used with aggregate functions.
#
# Syntax:
#
#
# ```sql
# HAVING condition;
# ```
#
# Example:
#
#
# ```sql
# SELECT department, COUNT(*)
# FROM employees
# GROUP BY department
# HAVING COUNT(*) > 10;
# ```
#
# This query selects departments that have more than 10 employees.
#
# 6. `ORDER BY`The `ORDER BY` clause is used to sort the result set in either ascending (`ASC`) or descending (`DESC`) order based on one or more columns.
#
# Syntax:
#
#
# ```sql
# ORDER BY column1 [ASC|DESC], column2 [ASC|DESC], ...;
# ```
#
# Example:
#
#
# ```sql
# SELECT name, age
# FROM students
# WHERE age > 18
# ORDER BY age DESC;
# ```
#
# This sorts the students who are older than 18 by age in descending order.
#
#
# ---
#
#
# Complete Example:
#
#
# ```sql
# SELECT department, COUNT(*) AS total_employees
# FROM employees
# WHERE salary > 50000
# GROUP BY department
# HAVING COUNT(*) > 10
# ORDER BY total_employees DESC;
# ```
#
# In this example:
#
# - We are selecting departments and counting the number of employees.
#
# - The `WHERE` clause filters employees with a salary greater than 50,000.
#
# - The `GROUP BY` groups the results by department.
#
# - The `HAVING` clause filters the grouped results to show only departments with more than 10 employees.
#
# - The `ORDER BY` sorts the final results in descending order based on the number of employees.
#
#
# ---
#
#
# Practice
#
# Try to build your own SQL queries using this structure. Start with a basic `SELECT` and gradually add the `WHERE`, `GROUP BY`, `HAVING`, and `ORDER BY` clauses based on your data and analysis requirements.

# %% [markdown]
# ## CREATE TABLE

# %% [markdown]
# 1. **Basic `CREATE TABLE` Syntax** To create a table, you use the `CREATE TABLE` statement. You must define the table name and the columns along with their data types.
#
# ```sql
# CREATE TABLE table_name (
#     column1 datatype constraint,
#     column2 datatype constraint,
#     column3 datatype constraint,
#     ...
# );
# ```
#
# - `table_name`: The name of the table.
#
# - `column1, column2, column3`: The names of the columns in the table.
#
# - `datatype`: Specifies the data type of the column (e.g., `INT`, `VARCHAR`, `DATE`, etc.).
#
# - `constraint`: Optional. You can add constraints like `NOT NULL`, `UNIQUE`, `PRIMARY KEY`, etc.
#
# 2. **Example: Creating a Table**
# Let's create a table to store information about employees:
#
#
# ```sql
# CREATE TABLE Employees (
#     EmployeeID INT PRIMARY KEY,
#     FirstName VARCHAR(50) NOT NULL,
#     LastName VARCHAR(50) NOT NULL,
#     BirthDate DATE,
#     Email VARCHAR(100) UNIQUE,
#     HireDate DATE,
#     Salary DECIMAL(10, 2)
# );
# ```
#
# - `EmployeeID`: Primary key of the table (each employee will have a unique ID).
#
# - `FirstName` and `LastName`: Both are `VARCHAR(50)` and cannot be null.
#
# - `BirthDate`: A `DATE` column.
#
# - `Email`: A `VARCHAR(100)` with a `UNIQUE` constraint, meaning no two employees can have the same email address.
#
# - `HireDate`: Another `DATE` column.
#
# - `Salary`: A `DECIMAL(10, 2)` type, which can store up to 10 digits with 2 decimal places.
#
# 3. **Adding Constraints**
# You can add constraints to ensure data integrity. Some common constraints include:
#
# - **`PRIMARY KEY`** : Uniquely identifies each record.
#
# - **`NOT NULL`** : Ensures that a column cannot have `NULL` values.
#
# - **`UNIQUE`** : Ensures all values in a column are unique.
#
# - **`DEFAULT`** : Specifies a default value if none is provided.
#
# - **`CHECK`** : Ensures all values in a column meet a specific condition.
#
# Example:
#
#
# ```sql
# CREATE TABLE Products (
#     ProductID INT PRIMARY KEY,
#     ProductName VARCHAR(100) NOT NULL,
#     Price DECIMAL(10, 2) CHECK (Price > 0),
#     Stock INT DEFAULT 0
# );
# ```
#
# In this table:
#
# - `Price` must be greater than zero (`CHECK` constraint).
#
# - If `Stock` is not provided, it defaults to 0 (`DEFAULT` constraint).
#
# 4. **`AUTO_INCREMENT`/`SERIAL`** For tables that require an auto-incrementing column (like `EmployeeID`), you can use `AUTO_INCREMENT` in MySQL or `SERIAL` in PostgreSQL.
# Example for MySQL:
#
#
# ```sql
# CREATE TABLE Employees (
#     EmployeeID INT AUTO_INCREMENT PRIMARY KEY,
#     FirstName VARCHAR(50) NOT NULL,
#     LastName VARCHAR(50) NOT NULL
# );
# ```
#
# In PostgreSQL, you can use:
#
#
# ```sql
# CREATE TABLE Employees (
#     EmployeeID SERIAL PRIMARY KEY,
#     FirstName VARCHAR(50) NOT NULL,
#     LastName VARCHAR(50) NOT NULL
# );
# ```
# 5. **Foreign Keys**
# You can use foreign keys to create relationships between tables.
#
# Example:
#
#
# ```sql
# CREATE TABLE Departments (
#     DepartmentID INT PRIMARY KEY,
#     DepartmentName VARCHAR(100) NOT NULL
# );
#
# CREATE TABLE Employees (
#     EmployeeID INT PRIMARY KEY,
#     FirstName VARCHAR(50) NOT NULL,
#     LastName VARCHAR(50) NOT NULL,
#     DepartmentID INT,
#     FOREIGN KEY (DepartmentID) REFERENCES Departments(DepartmentID)
# );
# ```
# In this example, `DepartmentID` in the `Employees` table is a foreign key that references the `DepartmentID` in the `Departments` table.
#
# 6. **Altering a Table** If you need to modify an existing table (add, modify, or drop columns), you can use the `ALTER TABLE` statement.
# Example to add a new column:
#
#
# ```sql
# ALTER TABLE Employees ADD PhoneNumber VARCHAR(15);
# ```
#
# 7. **Dropping a Table**
# To delete an existing table, you can use:
#
#
# ```sql
# DROP TABLE table_name;
# ```
#
# Example:
#
#
# ```sql
# DROP TABLE Employees;
# ```

# %% [markdown]
# ## INSERT and DELETE

# %% [markdown]
# 1. **SQL to Add a Row (INSERT)** To add a row into a table, you use the `INSERT INTO` statement.
#
# ```sql
# INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);
# ```
#
# Example:
# If you have a table called `employees` with columns `employee_id`, `first_name`, `last_name`, and `email`, and you want to add a new employee:
#
# ```sql
# INSERT INTO employees (employee_id, first_name, last_name, email)
# VALUES (101, 'John', 'Doe', 'john.doe@example.com');
# ```
# 2. **SQL to Delete a Row (DELETE)** To delete a row, you use the `DELETE FROM` statement along with a condition (`WHERE` clause) to specify which row(s) to delete. Be cautious when using the `DELETE` statement without a `WHERE` clause, as it will delete all rows from the table.
#
# ```sql
# DELETE FROM table_name
# WHERE condition;
# ```
#
# Example:
# If you want to delete the row where `employee_id` is `101` from the `employees` table:
#
# ```sql
# DELETE FROM employees
# WHERE employee_id = 101;
# ```

# %% [markdown]
# ## SQL datatypes

# %% [markdown]
# SQL datatypes define the kind of data that can be stored in a database column. Here is a summary of common SQL datatypes:
#
# 1. **Numeric Datatypes**
# - **INT** : Integer value, used for whole numbers (e.g., 1, 100, -50).
#
# - **FLOAT** : Floating point number with approximate precision.
#
# - **DECIMAL (M, D) / NUMERIC (M, D)** : Fixed-point numbers with exact precision, where `M` is the total number of digits and `D` is the number of digits after the decimal point.
#
# - **BIGINT** : Larger range of integer values.
#
# - **SMALLINT** : Smaller range of integer values.
#
# - **TINYINT** : Very small range of integer values.
#
# 2. **String (Character) Datatypes**
# - **CHAR(n)** : Fixed-length character string. `n` defines the length of the string.
#
# - **VARCHAR(n)** : Variable-length string. `n` defines the maximum length of the string.
#
# - **TEXT** : Variable-length text, often used for large blocks of text.
#
# - **BLOB** : Binary large object, used for storing binary data like images or files.
#
# 3. **Date and Time Datatypes**
# - **DATE** : Date in the format `YYYY-MM-DD`.
#
# - **TIME** : Time in the format `HH:MM:SS`.
#
# - **DATETIME** : Combination of date and time in the format `YYYY-MM-DD HH:MM:SS`.
#
# - **TIMESTAMP** : Stores date and time but is typically used for tracking record changes.
#
# - **YEAR** : Stores a year in either two digits or four digits format.
#
# 4. **Boolean Datatype**
#
# - **BOOLEAN** : Stores TRUE or FALSE values. Often represented internally as `TINYINT` with `0` for FALSE and `1` for TRUE.
#
# 5. **Binary Datatypes**
#
# - **BINARY(n)** : Fixed-length binary data.
#
# - **VARBINARY(n)** : Variable-length binary data.
#
# 6. **Miscellaneous Datatypes**
#
# - **ENUM** : A string object with a predefined set of values (e.g., `ENUM('small', 'medium', 'large')`).
#
# - **SET** : Similar to ENUM, but allows multiple values from the predefined set to be stored.
#
# - **JSON** : Stores JSON formatted data (available in some database systems like MySQL).
#
# - **UUID** : Universally unique identifier, used for unique key generation.
#
# **Notes:**
#
# - The choice of datatype affects the performance and storage requirements of the database, so it's important to select the most appropriate type based on the data being stored.

# %% [markdown]
# ## JupySQL

# %% [markdown]
# **JupySQL:** [https://jupysql.ploomber.io/en/latest/quick-start.html](https://jupysql.ploomber.io/en/latest/quick-start.html)

# %% [markdown]
# ## My Code Here

# %%
# Mount your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change current directory
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/M6_SQL"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/M6_SQL

# %%
# Verify the current directory
# %ls
# Out:
# CAHousing.db  City.db  LifeSatisfaction.db  SQL_Notes.ipynb  Students.db  Tips.db

# %%
# Verify the current directory
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500Fall2024/LiveSession/M6_SQL'

# %% [markdown]
# ### Install python packages for SQL

# %%
# pandas matplot
import pandas

# %%
# %pip install pandas

# %%
# %pip install jupysql duckdb duckdb-engine --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.4 MB/s eta 0:00:00

# %% [markdown]
# ### Load the SQL extension

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Display limit

# %%
# Setting: Show all rows
# %config SqlMagic.displaylimit = None
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %% [markdown]
# ### Connect to SQLite database

# %% [markdown]
# ```text
# City.db
# CAHousing.db
# Tips.db
# LifeSatisfaction.db
# Students.db
# ```

# %% [markdown]
# This is how to connect to a SQLite Database file.
# ```sql
# %sql sqlite:///sqlite_db_filename
# ```

# %% [markdown]
# ### Explore the database
#
# **Show tables**
# ```sql
# %sqlcmd tables
# ```
#
# **Show columns in a table**
# ```sql
# %sqlcmd columns -t tablename
# ```

# %% [markdown]
# ### **%sql** vs **%%sql**

# %% [markdown]
# **%sql**: sql should be in one line.
#
#
# **%%sql**: sql can be in multiple lines.

# %%
# %ls
# Out:
# CAHousing.db  City.db  LifeSatisfaction.db  SQL_Notes.ipynb  Students.db  Tips.db

# %%
# connect to db file
# %sql sqlite:///Students.db
# Out:
# Connecting to 'sqlite:///Students.db'

# %%
# %sqlcmd tables
# Out:
# +-------------+
# |     Name    |
# +-------------+
# |   Courses   |
# | Enrollments |
# |   Profiles  |
# |   Students  |
# +-------------+

# %%
# %sqlcmd columns -t Students
# Out:
# +----------+------+----------+---------+-------------+
# |   name   | type | nullable | default | primary_key |
# +----------+------+----------+---------+-------------+
# |    Id    | TEXT |  False   |   None  |      1      |
# |   Name   | TEXT |  False   |   None  |      0      |
# |   DOB    | TEXT |  False   |   None  |      0      |
# | favPlace | TEXT |  False   |   None  |      0      |
# |   lon    | REAL |  False   |   None  |      0      |
# |   lat    | REAL |  False   |   None  |      0      |
# +----------+------+----------+---------+-------------+

# %%
# %sqlcmd columns -t Enrollments
# Out:
# +-------------+---------+----------+---------+-------------+
# |     name    |   type  | nullable | default | primary_key |
# +-------------+---------+----------+---------+-------------+
# |      Id     | INTEGER |  False   |   None  |      1      |
# |   CourseId  |   TEXT  |  False   |   None  |      0      |
# |  StudentId  |   TEXT  |  False   |   None  |      0      |
# |    Grade    |   REAL  |  False   |   None  |      0      |
# | LetterGrade |   TEXT  |  False   |   None  |      0      |
# |   Created   |   TEXT  |  False   |   None  |      0      |
# +-------------+---------+----------+---------+-------------+

# %%
# %sql select * from [Students] limit 3
# Out:
# Running query in 'sqlite:///Students.db'
# +-------+--------------------+-----------------------------------+------------+--------------+------------+
# |   Id  |        Name        |                DOB                |  favPlace  |     lon      |    lat     |
# +-------+--------------------+-----------------------------------+------------+--------------+------------+
# | S1001 |       Tommy        |             1978-02-21            | Marysville | -122.1770818 | 48.0517637 |
# | S1004 | William H Ginsburg | 1943-03-25 06:00:00.000000 +00:00 | Worcester  | -71.8022934  | 42.2625932 |
# | S1005 |    Julius Rudel    | 1921-03-06 06:00:00.000000 +00:00 |  Columbia  | -81.0348144  | 34.0007104 |
# +-------+--------------------+-----------------------------------+------------+--------------+------------+

# %%
# %%sql
# select *
# from [Students]
# limit 4
# Out:
# Running query in 'sqlite:///Students.db'
# +-------+--------------------+-----------------------------------+------------+--------------+------------+
# |   Id  |        Name        |                DOB                |  favPlace  |     lon      |    lat     |
# +-------+--------------------+-----------------------------------+------------+--------------+------------+
# | S1001 |       Tommy        |             1978-02-21            | Marysville | -122.1770818 | 48.0517637 |
# | S1004 | William H Ginsburg | 1943-03-25 06:00:00.000000 +00:00 | Worcester  | -71.8022934  | 42.2625932 |
# | S1005 |    Julius Rudel    | 1921-03-06 06:00:00.000000 +00:00 |  Columbia  | -81.0348144  | 34.0007104 |
# | S1006 |    Paul Gauguin    | 1848-06-07 06:00:00.000000 +00:00 | Waterbury  | -73.0514965  | 41.5581525 |
# +-------+--------------------+-----------------------------------+------------+--------------+------------+

# %%
# %%sql
# select *
# from [Enrollments]
# limit 10
# Out:
# Running query in 'sqlite:///Students.db'
# +----+----------+-----------+-------------------+-------------+-----------------------------------+
# | Id | CourseId | StudentId |       Grade       | LetterGrade |              Created              |
# +----+----------+-----------+-------------------+-------------+-----------------------------------+
# | 1  | MIS3013  |   S1988   | 78.51722281550516 |      C      | 2023-04-23 20:51:00.000000 +00:00 |
# | 2  | MIS3013  |   S1130   | 87.25482683802389 |      B      | 2023-04-23 20:51:00.000000 +00:00 |
# | 3  | MIS3013  |   S1223   | 78.83439331131662 |      C      | 2023-04-23 20:51:00.000000 +00:00 |
# | 4  | MIS3013  |   S1074   | 77.21221007855507 |      C      | 2023-04-23 20:51:00.000000 +00:00 |
# | 5  | MIS3013  |   S1262   | 92.31732619299135 |      A      | 2023-04-23 20:51:00.000000 +00:00 |
# | 6  | MIS3013  |   S1558   |  70.1002839423159 |      C      | 2023-04-23 20:51:00.000000 +00:00 |
# ...

# %%
# %%sql
# select [CourseId],[Grade],[LetterGrade]
# from [Enrollments]
# limit 10
# Out:
# Running query in 'sqlite:///Students.db'
# +----------+-------------------+-------------+
# | CourseId |       Grade       | LetterGrade |
# +----------+-------------------+-------------+
# | MIS3013  | 78.51722281550516 |      C      |
# | MIS3013  | 87.25482683802389 |      B      |
# | MIS3013  | 78.83439331131662 |      C      |
# | MIS3013  | 77.21221007855507 |      C      |
# | MIS3013  | 92.31732619299135 |      A      |
# | MIS3013  |  70.1002839423159 |      C      |
# | MIS3013  | 32.97835320914948 |      F      |
# | MIS3013  | 79.27423805750861 |      C      |
# | MIS3013  |  92.5241210831345 |      A      |
# | MIS3013  | 98.37414485352878 |      A      |
# +----------+-------------------+-------------+

# %%
# %%sql
# select [CourseId] as [C],[Grade] as [G],[LetterGrade] as [LG]
# from [Enrollments]
# limit 10
# Out:
# Running query in 'sqlite:///Students.db'
# +---------+-------------------+----+
# |    C    |         G         | LG |
# +---------+-------------------+----+
# | MIS3013 | 78.51722281550516 | C  |
# | MIS3013 | 87.25482683802389 | B  |
# | MIS3013 | 78.83439331131662 | C  |
# | MIS3013 | 77.21221007855507 | C  |
# | MIS3013 | 92.31732619299135 | A  |
# | MIS3013 |  70.1002839423159 | C  |
# | MIS3013 | 32.97835320914948 | F  |
# | MIS3013 | 79.27423805750861 | C  |
# | MIS3013 |  92.5241210831345 | A  |
# | MIS3013 | 98.37414485352878 | A  |
# +---------+-------------------+----+

# %%
# %%sql
# select *
# from [Enrollments]
# where [StudentId]="S1988" and [CourseId]="MIS3013"
# Out:
# Running query in 'sqlite:///Students.db'
# +----+----------+-----------+-------------------+-------------+-----------------------------------+
# | Id | CourseId | StudentId |       Grade       | LetterGrade |              Created              |
# +----+----------+-----------+-------------------+-------------+-----------------------------------+
# | 1  | MIS3013  |   S1988   | 78.51722281550516 |      C      | 2023-04-23 20:51:00.000000 +00:00 |
# +----+----------+-----------+-------------------+-------------+-----------------------------------+

# %%
# %%sql
# select *
# from [Enrollments]
# where [CourseId]="MIS3013" and [LetterGrade]="F"
# limit 10
# Out:
# Running query in 'sqlite:///Students.db'
# +----+----------+-----------+--------------------+-------------+-----------------------------------+
# | Id | CourseId | StudentId |       Grade        | LetterGrade |              Created              |
# +----+----------+-----------+--------------------+-------------+-----------------------------------+
# | 7  | MIS3013  |   S1922   | 32.97835320914948  |      F      | 2023-04-23 20:51:00.000000 +00:00 |
# | 12 | MIS3013  |   S1833   | 56.53495310747054  |      F      | 2023-04-23 20:51:00.000000 +00:00 |
# | 15 | MIS3013  |   S1286   | 26.21011712599811  |      F      | 2023-04-23 20:51:00.000000 +00:00 |
# | 18 | MIS3013  |   S1959   | 49.39090728023041  |      F      | 2023-04-23 20:51:00.000000 +00:00 |
# | 23 | MIS3013  |   S1121   | 51.82852322231619  |      F      | 2023-04-23 20:51:00.000000 +00:00 |
# | 29 | MIS3013  |   S1560   | 53.10672230530067  |      F      | 2023-04-23 20:51:00.000000 +00:00 |
# ...

# %%
# %%sql
# select count([StudentId]) as [N F], avg([Grade])
# from [Enrollments]
# where [CourseId]="MIS3013" and [LetterGrade]="F"
# Out:
# Running query in 'sqlite:///Students.db'
# +-----+--------------------+
# | N F |    avg([Grade])    |
# +-----+--------------------+
# |  76 | 40.111138153658615 |
# +-----+--------------------+

# %%
# %%sql
# select *
# from [Enrollments]
# where [CourseId]="MIS3013" and [LetterGrade]="D"
# order by [Grade] asc
# limit 10
# Out:
# Running query in 'sqlite:///Students.db'
# +-----+----------+-----------+--------------------+-------------+-----------------------------------+
# |  Id | CourseId | StudentId |       Grade        | LetterGrade |              Created              |
# +-----+----------+-----------+--------------------+-------------+-----------------------------------+
# | 393 | MIS3013  |   S1417   | 60.231427874024895 |      D      | 2023-04-23 20:51:00.000000 +00:00 |
# | 458 | MIS3013  |   S1025   | 60.44547811287296  |      D      | 2023-04-23 20:51:00.000000 +00:00 |
# | 128 | MIS3013  |   S1664   | 60.66855692977775  |      D      | 2023-04-23 20:51:00.000000 +00:00 |
# | 293 | MIS3013  |   S1111   | 60.86215005609121  |      D      | 2023-04-23 20:51:00.000000 +00:00 |
# | 111 | MIS3013  |   S1244   | 60.886805824758866 |      D      | 2023-04-23 20:51:00.000000 +00:00 |
# |  82 | MIS3013  |   S1867   | 60.90601231276774  |      D      | 2023-04-23 20:51:00.000000 +00:00 |
# ...

# %%
# Connect to SQLite database City.db
# %sql sqlite:///City.db
# Out:
# Connecting and switching to connection 'sqlite:///City.db'

# %%
# %sqlcmd tables
# Out:
# +------+
# | Name |
# +------+
# | data |
# +------+

# %%
#Show columns in the table: data
# %sqlcmd columns -t data
# Out:
# +------------+---------+----------+---------+-------------+
# |    name    |   type  | nullable | default | primary_key |
# +------------+---------+----------+---------+-------------+
# |     ID     | INTEGER |  False   |   None  |      1      |
# |    City    |   TEXT  |   True   |   None  |      0      |
# |   State    |   TEXT  |   True   |   None  |      0      |
# | Population | INTEGER |   True   |   None  |      0      |
# |    lat     |   REAL  |   True   |   None  |      0      |
# |    lon     |   REAL  |   True   |   None  |      0      |
# +------------+---------+----------+---------+-------------+

# %%
# %%sql
# select *
# from [data]
# limit 10
# Out:
# Running query in 'sqlite:///City.db'
# +----+------------+----------------+------------+--------------------+--------------+
# | ID |    City    |     State      | Population |        lat         |     lon      |
# +----+------------+----------------+------------+--------------------+--------------+
# | 1  | Marysville |   Washington   |   63269    |     48.0517637     | -122.1770818 |
# | 2  |   Perris   |   California   |   72326    |     33.7825194     | -117.2286478 |
# | 3  | Cleveland  |      Ohio      |   390113   |      41.49932      | -81.6943605  |
# | 4  | Worcester  | Massachusetts  |   182544   | 42.262593200000005 | -71.8022934  |
# | 5  |  Columbia  | South Carolina |   133358   |     34.0007104     | -81.0348144  |
# | 6  | Waterbury  |  Connecticut   |   109676   | 41.558152500000006 | -73.0514965  |
# | 7  |   Eagan    |   Minnesota    |   65453    | 44.804132200000005 | -93.1668858  |
# ...

# %%
# %%sql
# select *
# from [data]
# order by [Population] desc
# limit 10
# Out:
# Running query in 'sqlite:///City.db'
# +-----+--------------+--------------+------------+------------+---------------------+
# |  ID |     City     |    State     | Population |    lat     |         lon         |
# +-----+--------------+--------------+------------+------------+---------------------+
# | 891 |   New York   |   New York   |  8405837   | 40.7127837 |  -74.00594129999999 |
# | 954 | Los Angeles  |  California  |  3884307   | 34.0522342 | -118.24368490000002 |
# | 595 |   Chicago    |   Illinois   |  2718782   | 41.8781136 |  -87.62979820000001 |
# | 647 |   Houston    |    Texas     |  2195914   | 29.7604267 |     -95.3698028     |
# |  54 | Philadelphia | Pennsylvania |  1553165   | 39.9525839 |     -75.1652215     |
# | 967 |   Phoenix    |   Arizona    |  1513367   | 33.4483771 |     -112.0740373    |
# | 154 | San Antonio  |    Texas     |  1409019   | 29.4241219 |     -98.4936282     |
# ...

# %%
# %%sql
# select *
# from [data]
# where [State]="Utah"
# Out:
# Running query in 'sqlite:///City.db'
# +-----+------------------+-------+------------+--------------------+---------------------+
# |  ID |       City       | State | Population |        lat         |         lon         |
# +-----+------------------+-------+------------+--------------------+---------------------+
# |  32 |      Logan       |  Utah |   48913    |     41.7369803     |     -111.8338359    |
# | 194 |   South Jordan   |  Utah |   59366    |     40.5621704     |     -111.929658     |
# | 286 |    Bountiful     |  Utah |   43023    |     40.8893895     |     -111.880771     |
# | 382 |      Provo       |  Utah |   116288   |     40.2338438     |     -111.6585337    |
# | 435 |   Spanish Fork   |  Utah |   36956    |     40.114955      |     -111.654923     |
# | 441 |   Taylorsville   |  Utah |   60519    |     40.6677248     |     -111.9388258    |
# | 467 |     Riverton     |  Utah |   40921    |     40.521893      |     -111.9391023    |
# ...

# %%
# %%sql
# select *
# from [data]
# where [State]="Utah"
# order by [Population] desc
# Out:
# Running query in 'sqlite:///City.db'
# +-----+------------------+-------+------------+--------------------+---------------------+
# |  ID |       City       | State | Population |        lat         |         lon         |
# +-----+------------------+-------+------------+--------------------+---------------------+
# | 965 |  Salt Lake City  |  Utah |   191180   |     40.7607793     | -111.89104740000002 |
# | 674 | West Valley City |  Utah |   133579   | 40.691613200000006 |     -112.0010501    |
# | 382 |      Provo       |  Utah |   116288   |     40.2338438     |     -111.6585337    |
# | 956 |   West Jordan    |  Utah |   110077   |     40.6096698     |     -111.9391031    |
# | 677 |       Orem       |  Utah |   91648    |     40.2968979     | -111.69464750000002 |
# | 631 |      Sandy       |  Utah |   90231    | 40.564978100000005 |     -111.8389726    |
# | 534 |      Ogden       |  Utah |   84249    |       41.223       |     -111.9738304    |
# ...

# %%
# %%sql
# select count(*) as [N]
# from [data]
# where [State]="Utah"
# Out:
# Running query in 'sqlite:///City.db'
# +----+
# | N  |
# +----+
# | 19 |
# +----+

# %%
# %%sql
# select sum([Population]) as [SUM POP], avg([Population]) as [AVG POP]
# from [data]
# where [State]="Utah"
# Out:
# Running query in 'sqlite:///City.db'
# +---------+-------------------+
# | SUM POP |      AVG POP      |
# +---------+-------------------+
# | 1440569 | 75819.42105263157 |
# +---------+-------------------+

# %%
# %%sql
# select [City] as [C], max([Population]) as [MAX POP]
# from [data]
# where [State]="Utah"
# Out:
# Running query in 'sqlite:///City.db'
# +----------------+---------+
# |       C        | MAX POP |
# +----------------+---------+
# | Salt Lake City |  191180 |
# +----------------+---------+

# %%
# get all cities with population between 1 million and 2 million
# %%sql
select *
from [data]
where [Population]>=1000000 and [Population]<=2000000
# Out:
# Running query in 'sqlite:///City.db'
# +-----+--------------+--------------+------------+------------+--------------+
# |  ID |     City     |    State     | Population |    lat     |     lon      |
# +-----+--------------+--------------+------------+------------+--------------+
# |  54 | Philadelphia | Pennsylvania |  1553165   | 39.9525839 | -75.1652215  |
# |  60 |    Dallas    |    Texas     |  1257676   | 32.7766642 | -96.7969879  |
# | 154 | San Antonio  |    Texas     |  1409019   | 29.4241219 | -98.4936282  |
# | 334 |  San Diego   |  California  |  1355896   | 32.715738  | -117.1610838 |
# | 967 |   Phoenix    |   Arizona    |  1513367   | 33.4483771 | -112.0740373 |
# +-----+--------------+--------------+------------+------------+--------------+

# %%
# %%sql
# select *
# from [data]
# where [Population]>1000000 and [State] in ("Texas","Arizona")
# Out:
# Running query in 'sqlite:///City.db'
# +-----+-------------+---------+------------+------------+--------------+
# |  ID |     City    |  State  | Population |    lat     |     lon      |
# +-----+-------------+---------+------------+------------+--------------+
# |  60 |    Dallas   |  Texas  |  1257676   | 32.7766642 | -96.7969879  |
# | 154 | San Antonio |  Texas  |  1409019   | 29.4241219 | -98.4936282  |
# | 647 |   Houston   |  Texas  |  2195914   | 29.7604267 | -95.3698028  |
# | 967 |   Phoenix   | Arizona |  1513367   | 33.4483771 | -112.0740373 |
# +-----+-------------+---------+------------+------------+--------------+

# %%
# %%sql
# select *
# from [data]
# where [Population] between 1000000 and 2000000
# Out:
# Running query in 'sqlite:///City.db'
# +-----+--------------+--------------+------------+------------+--------------+
# |  ID |     City     |    State     | Population |    lat     |     lon      |
# +-----+--------------+--------------+------------+------------+--------------+
# |  54 | Philadelphia | Pennsylvania |  1553165   | 39.9525839 | -75.1652215  |
# |  60 |    Dallas    |    Texas     |  1257676   | 32.7766642 | -96.7969879  |
# | 154 | San Antonio  |    Texas     |  1409019   | 29.4241219 | -98.4936282  |
# | 334 |  San Diego   |  California  |  1355896   | 32.715738  | -117.1610838 |
# | 967 |   Phoenix    |   Arizona    |  1513367   | 33.4483771 | -112.0740373 |
# +-----+--------------+--------------+------------+------------+--------------+

# %%
# get all cities with population between 1 million and 2 million

# %%
# get all cities in Utah
# %%sql
select *
from [data]
where [State] = "Utah"
# Out:
# Running query in 'sqlite:///City.db'
# +-----+------------------+-------+------------+--------------------+---------------------+
# |  ID |       City       | State | Population |        lat         |         lon         |
# +-----+------------------+-------+------------+--------------------+---------------------+
# |  32 |      Logan       |  Utah |   48913    |     41.7369803     |     -111.8338359    |
# | 194 |   South Jordan   |  Utah |   59366    |     40.5621704     |     -111.929658     |
# | 286 |    Bountiful     |  Utah |   43023    |     40.8893895     |     -111.880771     |
# | 382 |      Provo       |  Utah |   116288   |     40.2338438     |     -111.6585337    |
# | 435 |   Spanish Fork   |  Utah |   36956    |     40.114955      |     -111.654923     |
# | 441 |   Taylorsville   |  Utah |   60519    |     40.6677248     |     -111.9388258    |
# | 467 |     Riverton     |  Utah |   40921    |     40.521893      |     -111.9391023    |
# ...

# %%
# get all cities in Utah
# %%sql
select *
from [data]
where [State] in ("Utah")
# Out:
# Running query in 'sqlite:///City.db'
# +-----+------------------+-------+------------+--------------------+---------------------+
# |  ID |       City       | State | Population |        lat         |         lon         |
# +-----+------------------+-------+------------+--------------------+---------------------+
# |  32 |      Logan       |  Utah |   48913    |     41.7369803     |     -111.8338359    |
# | 194 |   South Jordan   |  Utah |   59366    |     40.5621704     |     -111.929658     |
# | 286 |    Bountiful     |  Utah |   43023    |     40.8893895     |     -111.880771     |
# | 382 |      Provo       |  Utah |   116288   |     40.2338438     |     -111.6585337    |
# | 435 |   Spanish Fork   |  Utah |   36956    |     40.114955      |     -111.654923     |
# | 441 |   Taylorsville   |  Utah |   60519    |     40.6677248     |     -111.9388258    |
# | 467 |     Riverton     |  Utah |   40921    |     40.521893      |     -111.9391023    |
# ...

# %%
# get all cities in Utah, only keep columns: City, State, and Population
# %%sql
select [City] as [C],[State] as [S],[Population] as [P]
from [data]
where [State]="Utah"
# Out:
# Running query in 'sqlite:///City.db'
# +------------------+------+--------+
# |        C         |  S   |   P    |
# +------------------+------+--------+
# |      Logan       | Utah | 48913  |
# |   South Jordan   | Utah | 59366  |
# |    Bountiful     | Utah | 43023  |
# |      Provo       | Utah | 116288 |
# |   Spanish Fork   | Utah | 36956  |
# |   Taylorsville   | Utah | 60519  |
# |     Riverton     | Utah | 40921  |
# |       Lehi       | Utah | 54382  |
# |      Ogden       | Utah | 84249  |
# |      Layton      | Utah | 70790  |
# |      Murray      | Utah | 48612  |
# |      Sandy       | Utah | 90231  |
# | West Valley City | Utah | 133579 |
# |       Orem       | Utah | 91648  |
# |       Roy        | Utah | 37733  |
# |      Draper      | Utah | 45285  |
# |    St. George    | Utah | 76817  |
# |   West Jordan    | Utah | 110077 |
# |  Salt Lake City  | Utah | 191180 |
# +------------------+------+--------+

# %%
# get all cities in Utah, only keep columns: City, State, and Population
# change the result column names to: C,S,P

# %%
# get how many cities in Utah in this dataset (table)
# %%sql
select count(*) as [COUNT]
from [data]
where [State] in ("Utah")
# Out:
# Running query in 'sqlite:///City.db'
# +-------+
# | COUNT |
# +-------+
# |   19  |
# +-------+

# %%
# get how many cities in Utah in this dataset (table). Change the column name to COUNT

# %%
# get the city with maximum population in Utah
# %%sql
select [City],max([Population]) as [MAX POP]
from [data]
where [State]="Utah"
# Out:
# Running query in 'sqlite:///City.db'
# +----------------+---------+
# |      City      | MAX POP |
# +----------------+---------+
# | Salt Lake City |  191180 |
# +----------------+---------+

# %%
# %%sql
# select [State],count([City]) as [N]
# from [data]
# where [State] in ("Utah")
# Out:
# Running query in 'sqlite:///City.db'
# +-------+----+
# | State | N  |
# +-------+----+
# |  Utah | 19 |
# +-------+----+

# %%
# Count how many cities in each state in this dataset (table)

# %%
# %%sql
# select [State], count(*) as [N]
# from [data]
# group by [State]
# having count(*)>10
# Out:
# Running query in 'sqlite:///City.db'
# +----------------+-----+
# |     State      |  N  |
# +----------------+-----+
# |    Alabama     |  12 |
# |    Arizona     |  25 |
# |   California   | 212 |
# |    Colorado    |  21 |
# |  Connecticut   |  15 |
# |    Florida     |  73 |
# |    Georgia     |  18 |
# |    Illinois    |  52 |
# |    Indiana     |  21 |
# |      Iowa      |  13 |
# |     Kansas     |  11 |
# | Massachusetts  |  36 |
# |    Michigan    |  31 |
# |   Minnesota    |  24 |
# |    Missouri    |  16 |
# |   New Jersey   |  22 |
# |    New York    |  17 |
# | North Carolina |  22 |
# |      Ohio      |  33 |
# |    Oklahoma    |  11 |
# |     Oregon     |  14 |
# |  Pennsylvania  |  13 |
# | South Carolina |  12 |
# |   Tennessee    |  17 |
# |     Texas      |  83 |
# |      Utah      |  19 |
# |    Virginia    |  17 |
# |   Washington   |  28 |
# |   Wisconsin    |  20 |
# +----------------+-----+

# %%
# %%sql
# select [State], count(*) as [N]
# from [data]
# group by [State]
# order by [N] desc
# Out:
# Running query in 'sqlite:///City.db'
# +----------------------+-----+
# |        State         |  N  |
# +----------------------+-----+
# |      California      | 212 |
# |        Texas         |  83 |
# |       Florida        |  73 |
# |       Illinois       |  52 |
# |    Massachusetts     |  36 |
# |         Ohio         |  33 |
# |       Michigan       |  31 |
# |      Washington      |  28 |
# |       Arizona        |  25 |
# |      Minnesota       |  24 |
# |    North Carolina    |  22 |
# |      New Jersey      |  22 |
# |       Indiana        |  21 |
# |       Colorado       |  21 |
# |      Wisconsin       |  20 |
# |         Utah         |  19 |
# |       Georgia        |  18 |
# |       Virginia       |  17 |
# |      Tennessee       |  17 |
# |       New York       |  17 |
# |       Missouri       |  16 |
# |     Connecticut      |  15 |
# |        Oregon        |  14 |
# |     Pennsylvania     |  13 |
# |         Iowa         |  13 |
# |    South Carolina    |  12 |
# ...

# %%
# %%sql
# select [State], sum([Population]) as [SUM POP], max([Population]) as [MAX POP]
# from [data]
# group by [State]
# order by [MAX POP] desc
# Out:
# Running query in 'sqlite:///City.db'
# +----------------------+----------+---------+
# |        State         | SUM POP  | MAX POP |
# +----------------------+----------+---------+
# |       New York       | 9933332  | 8405837 |
# |      California      | 27910620 | 3884307 |
# |       Illinois       | 6055539  | 2718782 |
# |        Texas         | 14836230 | 2195914 |
# |     Pennsylvania     | 2598080  | 1553165 |
# |       Arizona        | 4691466  | 1513367 |
# |       Indiana        | 2393472  |  843393 |
# |       Florida        | 7410114  |  842583 |
# |         Ohio         | 3480839  |  822553 |
# |    North Carolina    | 3358746  |  792862 |
# |       Michigan       | 2979267  |  688701 |
# |      Tennessee       | 2483464  |  653450 |
# |      Washington      | 2956938  |  652405 |
# |       Colorado       | 3012284  |  649495 |
# | District of Columbia |  646449  |  646449 |
# |    Massachusetts     | 3007084  |  645966 |
# |       Maryland       |  954852  |  622104 |
# ...

# %%
# %ls
# Out:
# CAHousing.db  LifeSatisfaction.db  Students.db      Students.db-wal
# City.db       SQL_Notes.ipynb      Students.db-shm  Tips.db

# %%
# %sql sqlite:///CAHousing.db
# Out:
# Connecting and switching to connection 'sqlite:///CAHousing.db'

# %%
# %sqlcmd tables
# Out:
# +------+
# | Name |
# +------+
# | data |
# +------+

# %%
# %sqlcmd columns -t data
# Out:
# +--------------------+---------+----------+---------+-------------+
# |        name        |   type  | nullable | default | primary_key |
# +--------------------+---------+----------+---------+-------------+
# |         ID         | INTEGER |  False   |   None  |      1      |
# |     longitude      |   REAL  |   True   |   None  |      0      |
# |      latitude      |   REAL  |   True   |   None  |      0      |
# | housing_median_age |   REAL  |   True   |   None  |      0      |
# |    total_rooms     | INTEGER |   True   |   None  |      0      |
# |   total_bedrooms   | INTEGER |   True   |   None  |      0      |
# |     population     | INTEGER |   True   |   None  |      0      |
# |     households     | INTEGER |   True   |   None  |      0      |
# |   median_income    |   REAL  |   True   |   None  |      0      |
# | median_house_value |   REAL  |   True   |   None  |      0      |
# |  ocean_proximity   |   TEXT  |   True   |   None  |      0      |
# ...

# %%
# %%sql
# select *
# from [data]
# limit 10
# Out:
# Running query in 'sqlite:///CAHousing.db'
# +----+-----------+----------+--------------------+-------------+----------------+------------+------------+---------------+--------------------+-----------------+
# | ID | longitude | latitude | housing_median_age | total_rooms | total_bedrooms | population | households | median_income | median_house_value | ocean_proximity |
# +----+-----------+----------+--------------------+-------------+----------------+------------+------------+---------------+--------------------+-----------------+
# | 1  |  -122.23  |  37.88   |        41.0        |     880     |      129       |    322     |    126     |     8.3252    |      452600.0      |     NEAR BAY    |
# | 2  |  -122.22  |  37.86   |        21.0        |     7099    |      1106      |    2401    |    1138    |     8.3014    |      358500.0      |     NEAR BAY    |
# ...

# %%
# %%sql
# select [ID],[population]
# from [data]
# order by [population] desc
# limit 10
# Out:
# Running query in 'sqlite:///CAHousing.db'
# +-------+------------+
# |   ID  | population |
# +-------+------------+
# | 12469 |   35682    |
# |  9697 |   28566    |
# |  5168 |   16305    |
# | 11502 |   16122    |
# | 18327 |   15507    |
# |  5924 |   15037    |
# | 12204 |   13251    |
# |  8003 |   12873    |
# | 16935 |   12427    |
# | 16409 |   12203    |
# +-------+------------+

# %%
# %%sql
# select *
# from [data]
# limit 10
# Out:
# Running query in 'sqlite:///CAHousing.db'
# +----+-----------+----------+--------------------+-------------+----------------+------------+------------+---------------+--------------------+-----------------+
# | ID | longitude | latitude | housing_median_age | total_rooms | total_bedrooms | population | households | median_income | median_house_value | ocean_proximity |
# +----+-----------+----------+--------------------+-------------+----------------+------------+------------+---------------+--------------------+-----------------+
# | 1  |  -122.23  |  37.88   |        41.0        |     880     |      129       |    322     |    126     |     8.3252    |      452600.0      |     NEAR BAY    |
# | 2  |  -122.22  |  37.86   |        21.0        |     7099    |      1106      |    2401    |    1138    |     8.3014    |      358500.0      |     NEAR BAY    |
# ...

# %%
# %%sql
# select count(*) as [N]
# from [data]
# where [housing_median_age] between 40 and 50
# Out:
# Running query in 'sqlite:///CAHousing.db'
# +------+
# |  N   |
# +------+
# | 2829 |
# +------+

# %%
# %ls
# Out:
# CAHousing.db  LifeSatisfaction.db  Students.db      Students.db-wal
# City.db       SQL_Notes.ipynb      Students.db-shm  Tips.db

# %%
# %sql sqlite:///Tips.db
# Out:
# Connecting and switching to connection 'sqlite:///Tips.db'

# %%
# %sqlcmd tables
# Out:
# +------+
# | Name |
# +------+
# | data |
# +------+

# %%
# %sqlcmd columns -t data
# Out:
# +------------+---------+----------+---------+-------------+
# |    name    |   type  | nullable | default | primary_key |
# +------------+---------+----------+---------+-------------+
# |     ID     | INTEGER |  False   |   None  |      1      |
# | total_bill |   REAL  |   True   |   None  |      0      |
# |    tip     |   REAL  |   True   |   None  |      0      |
# |    sex     |   TEXT  |   True   |   None  |      0      |
# |   smoker   |   TEXT  |   True   |   None  |      0      |
# |    day     |   TEXT  |   True   |   None  |      0      |
# |    time    |   TEXT  |   True   |   None  |      0      |
# |    size    | INTEGER |   True   |   None  |      0      |
# +------------+---------+----------+---------+-------------+

# %%
# %%sql
# select *
# from [data]
# order by [total_bill] desc
# limit 10
# Out:
# Running query in 'sqlite:///Tips.db'
# +-----+------------+------+--------+--------+------+--------+------+
# |  ID | total_bill | tip  |  sex   | smoker | day  |  time  | size |
# +-----+------------+------+--------+--------+------+--------+------+
# | 171 |   50.81    | 10.0 |  Male  |  Yes   | Sat  | Dinner |  3   |
# | 213 |   48.33    | 9.0  |  Male  |   No   | Sat  | Dinner |  4   |
# |  60 |   48.27    | 6.73 |  Male  |   No   | Sat  | Dinner |  4   |
# | 157 |   48.17    | 5.0  |  Male  |   No   | Sun  | Dinner |  6   |
# | 183 |   45.35    | 3.5  |  Male  |  Yes   | Sun  | Dinner |  3   |
# | 103 |    44.3    | 2.5  | Female |  Yes   | Sat  | Dinner |  3   |
# | 198 |   43.11    | 5.0  | Female |  Yes   | Thur | Lunch  |  4   |
# | 143 |   41.19    | 5.0  |  Male  |   No   | Thur | Lunch  |  5   |
# | 185 |   40.55    | 3.0  |  Male  |  Yes   | Sun  | Dinner |  2   |
# |  96 |   40.17    | 4.73 |  Male  |  Yes   | Fri  | Dinner |  4   |
# ...

# %%
# %%sql
# select *
# from [data]
# where [sex]="Female" and [day]="Sun"
# Out:
# Running query in 'sqlite:///Tips.db'
# +-----+------------+------+--------+--------+-----+--------+------+
# |  ID | total_bill | tip  |  sex   | smoker | day |  time  | size |
# +-----+------------+------+--------+--------+-----+--------+------+
# |  1  |   16.99    | 1.01 | Female |   No   | Sun | Dinner |  2   |
# |  5  |   24.59    | 3.61 | Female |   No   | Sun | Dinner |  4   |
# |  12 |   35.26    | 5.0  | Female |   No   | Sun | Dinner |  4   |
# |  15 |   14.83    | 3.02 | Female |   No   | Sun | Dinner |  2   |
# |  17 |   10.33    | 1.67 | Female |   No   | Sun | Dinner |  3   |
# |  19 |   16.97    | 3.5  | Female |   No   | Sun | Dinner |  3   |
# |  52 |   10.29    | 2.6  | Female |   No   | Sun | Dinner |  2   |
# |  53 |   34.81    | 5.2  | Female |   No   | Sun | Dinner |  4   |
# | 115 |   25.71    | 4.0  | Female |   No   | Sun | Dinner |  3   |
# | 116 |   17.31    | 3.5  | Female |   No   | Sun | Dinner |  2   |
# ...

# %%
# %%sql
# select [day],avg([tip]) as [AVG Tip]
# from [data]
# where [sex]="Male"
# group by [day]
# order by [AVG Tip] desc
# Out:
# Running query in 'sqlite:///Tips.db'
# +------+--------------------+
# | day  |      AVG Tip       |
# +------+--------------------+
# | Sun  | 3.2203448275862083 |
# | Sat  | 3.0838983050847455 |
# | Thur | 2.9803333333333333 |
# | Fri  |       2.693        |
# +------+--------------------+

# %%
# %%sql
# select [sex],avg([Tip]) as [AVG Tip]
# from [data]
# group by [sex]
# order by [AVG Tip] desc
# Out:
# Running query in 'sqlite:///Tips.db'
# +--------+--------------------+
# |  sex   |      AVG Tip       |
# +--------+--------------------+
# |  Male  | 3.0896178343949052 |
# | Female | 2.833448275862069  |
# +--------+--------------------+

# %%
# %%sql
# select [size],avg([Tip]) as [AVG Tip]
# from [data]
# group by [size]
# order by [AVG Tip] desc
# Out:
# Running query in 'sqlite:///Tips.db'
# +------+--------------------+
# | size |      AVG Tip       |
# +------+--------------------+
# |  6   |       5.225        |
# |  4   | 4.135405405405407  |
# |  5   | 4.0280000000000005 |
# |  3   | 3.393157894736842  |
# |  2   | 2.582307692307693  |
# |  1   |       1.4375       |
# +------+--------------------+

# %%
# %%sql
# select sum([households]) as [SUM H]
# from [data]
# Out:
# Running query in 'sqlite:///CAHousing.db'
# +----------+
# |  SUM H   |
# +----------+
# | 10204924 |
# +----------+

# %%
# %%sql
# select [ocean_proximity],count(*) as [N]
# from [data]
# group by [ocean_proximity]
# order by [N]
# Out:
# Running query in 'sqlite:///CAHousing.db'
# +-----------------+------+
# | ocean_proximity |  N   |
# +-----------------+------+
# |      ISLAND     |  5   |
# |     NEAR BAY    | 2270 |
# |    NEAR OCEAN   | 2628 |
# |      INLAND     | 6496 |
# |    <1H OCEAN    | 9034 |
# +-----------------+------+

# %% [markdown]
# <img width="600" src='data:image/svg+xml;base64,...'/>
